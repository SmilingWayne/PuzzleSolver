# %% [markdown]
# # Job Shop Problem (车间作业问题)
#
# 一个经典的车间调度问题，有多个任务，每个任务由多个作业组成。这些作业需要在多台机器上进行处理。问，如何把这些作业分配到这些机器上，使得完成每个作业的最晚时间尽可能地早。
#
# 同时，这些作业还需要满足一些约束。
#
# 1. 对于某个任务的多个作业，存在先后关系，必须先处理前面的作业，然后才能处理后面的。
# 2. 一台机器一次只能处理一个作业。
# 3. 一个作业一旦开始处理，那么就必须一直加工直到结束。
#
#
# -----
#
# ## 测试数据
#
# 一共3台机器，一共3个Job，每个Job的作业如下：
#
# Job0 : [(0, 3), (1, 2), (2, 2)]
#
# Job1 : [(0, 2), (2, 1), (1, 4)]
#
# Job2 : [(1, 4), (2, 3)]
#
# 其中，( m, p ) 记录一个作业的情况，m 表示作业必须在编号 m 的机器上加工， p 表示加工时间是 p 分钟。对于 Job 0， 必须先在机器0上完成持续时间3的作业，才能继续在机器1上完成持续时间2的作业。以此类推。最终需要把所有8个作业都安排到机器上。
#
# 一个可行的调度方案如下所示：（并非最优）
#
# ![](https://developers.google.cn/static/optimization/images/scheduling/schedule1.png)
#
#
# -----
#
# ## 模型概述
#
# 记 $\text{Task}_{i, j}$ 表示第 $i$ 个Job的第 $j$ 个作业。
#
# 决策变量：$t_{i,j}$ ，表示 $\text{Task}_{i, j}$ 的开始加工时间。
#
# 我们需要满足的约束：
#
# 1. 优先级约束：更加靠前的工序一定要更早地加工。以 Job0为例， $t_{0,2} + 2 \leq t_{0,3}$。第2个作业开始加工的时间 + 第2个作业的加工时间 $\leq$ 第3个作业开始加工的时间。
# 2. 无重叠约束：每个机器不能同时处理两个作业。首先每个机器需要处理的所有作业，我们是知道的，不知道的是处理的先后。那么，我们针对这些作业两两之间进行如下的判断以实现该约束：
#
# > 以 $\text{Task}_{0,2}$ 和 $\text{Task}_{2,1}$ 为例子，它们都在第一个机器上加工。
# >
# > 1. 如果 $\text{Task}_{0,2}$ 先加工，那么在他生产的时间内，$\text{Task}_{2,1}$ 一定不加工，所以有：
# >
# >  $t_{0,2} + 2 \leq t_{2,1}$
# >
# > 2. 如果 $\text{Task}_{2,1}$ 先加工，那么在他生产的时间内，$\text{Task}_{0,2}$ 一定不加工，所以有：
# >
# >  $t_{2,1} + 4 \leq t_{0,2}$
#
# 上述两者必定满足一个。
#
# 基于此，我们用ortools对这个 Job Shop Problem 进行求解。

# %% [markdown]
# # Flexible JSP （柔性作业车间调度）
#
# 场景依然不变，都是分配任务包含的作业到不同的机器上，从而最小化makespan.
#
# 但是区别是，每个作业不止可以在一个机器上加工，可以在多台机器中的任意一个进行加工。在不同机器上的加工时间（有可能）是不一样的。
#
# 现在也就是不仅需要决策什么时候处理这个作业，还需要决策在哪个机器上进行加工。

# %%
import collections
from ortools.sat.python import cp_model

# %%
def main(jobs_data) -> None:
    """
    Minimal jobshop problem.
    """
    
    # Data.
    # task = (machine_id, processing_time).
    # jobs_data = [  
    #     [(0, 3), (1, 2), (2, 2)],  # Job0
    #     [(0, 2), (2, 1), (1, 4)],  # Job1
    #     [(1, 4), (2, 3)],  # Job2
    # ]

    machines_count = 1 + max(task[0] for job in jobs_data for task in job)
    all_machines = range(machines_count)
    # Computes horizon dynamically as the sum of all durations.
    horizon = sum(task[1] for job in jobs_data for task in job) 
    
    # 假设所有工作只能在一台机器上加工，那么所需要的时间就是所有task的总时间 horizon，
    # 相当于约束每个作业开始加工时间的上界

    # Create the model.
    model = cp_model.CpModel()

    # Named tuple to store information about created variables.
    task_type = collections.namedtuple("task_type", "start end interval")
    # Named tuple to manipulate solution information.
    assigned_task_type = collections.namedtuple(
        "assigned_task_type", "start job index duration"
    )

    # Creates job intervals and add to the corresponding machine lists.
    all_tasks = {}
    machine_to_intervals = collections.defaultdict(list)

    for job_id, job in enumerate(jobs_data):
        for task_id, task in enumerate(job):
            machine, duration = task
            suffix = f"_{job_id}_{task_id}"
            start_var = model.new_int_var(0, horizon, "start" + suffix) # 工作开始时间的变量
            end_var = model.new_int_var(0, horizon, "end" + suffix) # 工作结束时间
            interval_var = model.new_interval_var( # 用 interval_var 表示一个工作占用了一个interval
                start_var, duration, end_var, "interval" + suffix
            )
            # 一个interval变量通过：开始t, 持续时间, 结束t来表示
            all_tasks[job_id, task_id] = task_type(
                start=start_var, end=end_var, interval=interval_var
            )
            machine_to_intervals[machine].append(interval_var)

    # for k, v in machine_to_intervals.items():
    #     print(k, v)
    # for k, v in all_tasks.items():
    #     print(k, v)
    # Create and add disjunctive constraints.
    for machine in all_machines:
        model.add_no_overlap(machine_to_intervals[machine])
        # 这里就是用到add_no_overlap函数的地方，结合interval变量进行使用，一个列表里的intervals不能重叠

    # Precedences inside a job.
    for job_id, job in enumerate(jobs_data):
        for task_id in range(len(job) - 1):
            model.add(
                all_tasks[job_id, task_id + 1].start >= all_tasks[job_id, task_id].end
            )

    # Makespan objective.
    obj_var = model.new_int_var(0, horizon, "makespan")
    model.add_max_equality(
        obj_var,
        [all_tasks[job_id, len(job) - 1].end for job_id, job in enumerate(jobs_data)],
    )
    # add_max_equality 的用法，含义是令前面声明的决策变量obj_var 等于下面列表中最晚的完成时间
    model.minimize(obj_var)

    # Creates the solver and solve.
    solver = cp_model.CpSolver()
    status = solver.solve(model)

    if status == cp_model.OPTIMAL or status == cp_model.FEASIBLE:
        print("Solution:")
        # Create one list of assigned tasks per machine.
        assigned_jobs = collections.defaultdict(list)
        for job_id, job in enumerate(jobs_data):
            for task_id, task in enumerate(job):
                machine = task[0]
                assigned_jobs[machine].append(
                    assigned_task_type(
                        start=solver.value(all_tasks[job_id, task_id].start),
                        job=job_id,
                        index=task_id,
                        duration=task[1],
                    )
                )

        # Create per machine output lines.
        output = ""
        for machine in all_machines:
            # Sort by starting time.
            assigned_jobs[machine].sort()
            sol_line_tasks = "Machine " + str(machine) + ": "
            sol_line = "           "

            for assigned_task in assigned_jobs[machine]:
                name = f"job_{assigned_task.job}_task_{assigned_task.index}"
                # add spaces to output to align columns.
                sol_line_tasks += f"{name:15}"

                start = assigned_task.start
                duration = assigned_task.duration
                sol_tmp = f"[{start},{start + duration}]"
                # add spaces to output to align columns.
                sol_line += f"{sol_tmp:15}"

            sol_line += "\n"
            sol_line_tasks += "\n"
            output += sol_line_tasks
            output += sol_line

        # Finally print the solution found.
        print(f"Optimal Schedule Length: {solver.objective_value}")
        print(output)
    else:
        print("No solution found.")

    # Statistics.
    print("\nStatistics")
    print(f"  - conflicts: {solver.num_conflicts}")
    print(f"  - branches : {solver.num_branches}")
    print(f"  - wall time: {solver.wall_time}s")


if __name__ == "__main__":
    jobs_data = [
        [(0, 3), (1, 2), (2, 2), (3, 5), (4,2)],
        [(0, 2), (2, 1), (1, 4), (2, 3), (3,1), (4, 2)],
        [(1, 4), (2, 3), (2, 4), (4, 2), (0, 3)],
        [(1, 2), (3, 4), (2, 3), (0, 2), (1, 1), (4, 3)]]
    
    main(jobs_data)
# Out:
# Solution:
# Optimal Schedule Length: 24.0
# Machine 0: job_0_task_0   job_1_task_0   job_3_task_3   job_2_task_4
#            [0,3]          [3,5]          [13,15]        [19,22]
# Machine 1: job_2_task_0   job_3_task_0   job_0_task_1   job_1_task_2   job_3_task_4
#            [0,4]          [4,6]          [6,8]          [8,12]         [15,16]
# Machine 2: job_2_task_1   job_1_task_1   job_0_task_2   job_3_task_2   job_2_task_2   job_1_task_3
#            [4,7]          [7,8]          [8,10]         [10,13]        [13,17]        [17,20]
# Machine 3: job_3_task_1   job_0_task_3   job_1_task_4
#            [6,10]         [10,15]        [20,21]
# Machine 4: job_0_task_4   job_2_task_3   job_3_task_5   job_1_task_5
#            [15,17]        [17,19]        [19,22]        [22,24]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 0
#   - wall time: 0.0046500000000000005s

# %% [markdown]
# # Test for 5 machine, 5 Jobs, each with 20 tasks

# %%
if __name__ == "__main__":

    import random
    random.seed(12345)
    jobs_data = []

    for _ in range(5):
        tmp = []
        for _ in range(20):
            tmp.append((random.randint(0, 4), random.randint(50, 150)))
        jobs_data.append(tmp)
    
    main(jobs_data)
# Out:
# Solution:
# Optimal Schedule Length: 2785.0
# Machine 0: job_4_task_0   job_1_task_1   job_0_task_1   job_2_task_2   job_2_task_3   job_3_task_3   job_3_task_4   job_2_task_6   job_3_task_5   job_0_task_11  job_2_task_9   job_4_task_10  job_2_task_11  job_0_task_15  job_4_task_14  job_4_task_15  job_1_task_16  job_4_task_17  job_0_task_17  job_2_task_16
#            [0,58]         [58,192]       [194,282]      [430,486]      [486,627]      [627,743]      [743,811]      [907,1055]     [1055,1189]    [1276,1393]    [1393,1504]    [1504,1587]    [1587,1717]    [1717,1791]    [1895,2025]    [2025,2094]    [2094,2165]    [2234,2319]    [2323,2431]    [2433,2554]
# Machine 1: job_3_task_0   job_3_task_1   job_1_task_2   job_4_task_2   job_3_task_2   job_4_task_4   job_4_task_5   job_0_task_8   job_4_task_6   job_1_task_10  job_4_task_8   job_0_task_14  job_1_task_13  job_3_task_11  job_3_task_12  job_3_task_14  job_3_task_15  job_1_task_18  job_2_task_17
#            [0,70]         [70,156]       [192,340]      [340,470]      [470,588]      [593,738]      [738,855]      [855,983]      [983,1075]     [1075,1140]    [1162,1280]    [1637,1713]    [1772,1854]    [1854,1935]    [1935,1988]    [2080,2180]    [2180,2252]    [2285,2364]    [2554,2614]
# Machine 2: job_2_task_0   job_0_task_2   job_0_task_3   job_1_task_4   job_0_task_5   job_1_task_9   job_2_task_7   job_0_task_10  job_3_task_8   job_4_task_12  job_0_task_16  job_3_task_13  job_4_task_16  job_1_task_17  job_2_task_15  job_1_task_19  job_0_task_18  job_4_task_19  job_2_task_19
#            [0,70]         [282,356]      [356,478]      [478,540]      [548,613]      [952,1007]     [1055,1132]    [1132,1276]    [1509,1623]    [1642,1758]    [1791,1882]    [1988,2080]    [2094,2234]    [2234,2285]    [2285,2433]    [2433,2552]    [2552,2605]    [2605,2706]    [2706,2785]
# Machine 3: job_1_task_0   job_0_task_0   job_4_task_1   job_2_task_1   job_0_task_4   job_1_task_5   job_0_task_6   job_1_task_7   job_2_task_4   job_2_task_5   job_1_task_11  job_3_task_6   job_0_task_12  job_4_task_11  job_3_task_9   job_3_task_10  job_2_task_12  job_4_task_18  job_3_task_18  job_2_task_18  job_3_task_19
#            [0,50]         [51,194]       [194,339]      [339,430]      [478,548]      [548,611]      [613,696]      [696,775]      [775,835]      [835,907]      [1140,1217]    [1217,1290]    [1393,1517]    [1587,1642]    [1642,1700]    [1700,1803]    [1803,1894]    [2319,2456]    [2470,2585]    [2614,2685]    [2685,2776]
# Machine 4: job_1_task_3   job_4_task_3   job_1_task_6   job_0_task_7   job_1_task_8   job_0_task_9   job_4_task_7   job_2_task_8   job_4_task_9   job_3_task_7   job_2_task_10  job_0_task_13  job_1_task_12  job_4_task_13  job_1_task_14  job_1_task_15  job_2_task_13  job_2_task_14  job_3_task_16  job_3_task_17  job_0_task_19
#            [340,412]      [470,593]      [611,684]      [696,826]      [826,952]      [983,1056]     [1075,1162]    [1162,1309]    [1309,1447]    [1447,1509]    [1509,1566]    [1566,1637]    [1637,1772]    [1772,1895]    [1895,2000]    [2000,2066]    [2066,2169]    [2169,2244]    [2252,2389]    [2389,2470]    [2605,2743]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 12
#   - wall time: 3.025294s

# %% [markdown]
# # Test for 10 machine, 5 Jobs, each with 20 tasks

# %%
if __name__ == "__main__":

    import random
    random.seed(12345)
    jobs_data = []

    for _ in range(5):
        tmp = []
        for _ in range(20):
            tmp.append((random.randint(0, 9), random.randint(50, 150)))
        jobs_data.append(tmp)
    
    main(jobs_data)
# Out:
# Solution:
# Optimal Schedule Length: 2472.0
# Machine 0: job_0_task_1   job_2_task_2   job_2_task_3   job_1_task_1   job_2_task_6   job_3_task_4   job_3_task_5   job_2_task_11  job_4_task_10  job_0_task_17  job_1_task_16  job_4_task_17
#            [143,231]      [234,290]      [290,431]      [431,565]      [569,717]      [717,785]      [785,919]      [1189,1319]    [1326,1409]    [1782,1890]    [1898,1969]    [2120,2205]
# Machine 1: job_4_task_0   job_3_task_3   job_2_task_9   job_0_task_11  job_0_task_15  job_4_task_14  job_4_task_15  job_2_task_16
#            [0,58]         [274,390]      [941,1052]     [1175,1292]    [1617,1691]    [1757,1887]    [1887,1956]    [1980,2101]
# Machine 2: job_3_task_1   job_3_task_2   job_1_task_2   job_4_task_5   job_0_task_8   job_4_task_8   job_3_task_11  job_3_task_12  job_0_task_14  job_1_task_13  job_3_task_14  job_3_task_15  job_1_task_18  job_2_task_17
#            [70,156]       [156,274]      [565,713]      [713,830]      [830,958]      [1070,1188]    [1407,1488]    [1488,1541]    [1541,1617]    [1634,1716]    [1716,1816]    [1816,1888]    [2020,2099]    [2101,2161]
# Machine 3: job_3_task_0   job_4_task_2   job_4_task_4   job_4_task_6   job_1_task_10
#            [0,70]         [203,333]      [456,601]      [830,922]      [1243,1308]
# Machine 4: job_0_task_3   job_1_task_4   job_3_task_8   job_1_task_17
#            [305,427]      [785,847]      [1132,1246]    [1969,2020]
# Machine 5: job_2_task_0   job_0_task_2   job_0_task_5   job_2_task_7   job_0_task_10  job_1_task_9   job_4_task_12  job_3_task_13  job_0_task_16  job_2_task_15  job_4_task_16  job_0_task_18  job_1_task_19  job_2_task_19  job_4_task_19
#            [0,70]         [231,305]      [497,562]      [717,794]      [1031,1175]    [1188,1243]    [1483,1599]    [1599,1691]    [1691,1782]    [1832,1980]    [1980,2120]    [2120,2173]    [2173,2292]    [2292,2371]    [2371,2472]
# Machine 6: job_0_task_0   job_2_task_1   job_1_task_0   job_0_task_4   job_2_task_5   job_0_task_6   job_1_task_5   job_1_task_7   job_3_task_9   job_0_task_12  job_4_task_11  job_3_task_18  job_3_task_19
#            [0,143]        [143,234]      [234,284]      [427,497]      [497,569]      [569,652]      [847,910]      [983,1062]     [1246,1304]    [1304,1428]    [1428,1483]    [2106,2221]    [2221,2312]
# Machine 7: job_4_task_1   job_2_task_4   job_3_task_6   job_3_task_10  job_1_task_11  job_2_task_12  job_2_task_18  job_4_task_18
#            [58,203]       [431,491]      [919,992]      [1304,1407]    [1407,1484]    [1484,1575]    [2161,2232]    [2232,2369]
# Machine 8: job_0_task_7   job_2_task_8   job_0_task_9   job_1_task_8   job_4_task_9   job_0_task_13  job_1_task_12  job_4_task_13  job_2_task_14  job_1_task_15  job_3_task_17  job_0_task_19
#            [652,782]      [794,941]      [958,1031]     [1062,1188]    [1188,1326]    [1428,1499]    [1499,1634]    [1634,1757]    [1757,1832]    [1832,1898]    [2025,2106]    [2173,2311]
# Machine 9: job_4_task_3   job_1_task_3   job_1_task_6   job_4_task_7   job_3_task_7   job_2_task_10  job_2_task_13  job_1_task_14  job_3_task_16
#            [333,456]      [713,785]      [910,983]      [983,1070]     [1070,1132]    [1132,1189]    [1575,1678]    [1716,1821]    [1888,2025]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 0
#   - wall time: 0.14408900000000002s

# %% [markdown]
# # Test for 5 machine, 10 Jobs, each with 20 tasks
#
# > 🤔 Not Solvable within given time

# %%
if __name__ == "__main__":

    import random
    random.seed(12345)
    jobs_data = []

    for _ in range(10):
        tmp = []
        for _ in range(20):
            tmp.append((random.randint(0, 4), random.randint(50, 150)))
        jobs_data.append(tmp)
    
    main(jobs_data)
    
    # Optimality?
# Out:
# Solution:
# Optimal Schedule Length: 4096.0
# Machine 0: job_4_task_0   job_1_task_1   job_0_task_1   job_2_task_2   job_2_task_3   job_3_task_3   job_3_task_4   job_2_task_6   job_3_task_5   job_7_task_4   job_7_task_5   job_2_task_9   job_5_task_4   job_2_task_11  job_0_task_11  job_4_task_10  job_9_task_6   job_5_task_8   job_5_task_9   job_9_task_7   job_0_task_15  job_4_task_14  job_2_task_16  job_0_task_17  job_4_task_15  job_7_task_15  job_7_task_16  job_9_task_11  job_5_task_15  job_7_task_17  job_4_task_17  job_8_task_14  job_6_task_14  job_5_task_17  job_1_task_16  job_9_task_16  job_8_task_16  job_8_task_17  job_6_task_18  job_5_task_19  job_7_task_19
#            [0,58]         [58,192]       [193,281]      [284,340]      [340,481]      [482,598]      [598,666]      [666,814]      [814,948]      [948,1045]     [1045,1144]    [1144,1255]    [1255,1338]    [1338,1468]    [1468,1585]    [1585,1668]    [1675,1791]    [1791,1844]    [1844,1971]    [1971,2086]    [2086,2160]    [2160,2290]    [2290,2411]    [2411,2519]    [2519,2588]    [2588,2710]    [2710,2822]    [2822,2925]    [2925,3053]    [3053,3115]    [3115,3200]    [3200,3333]    [3333,3395]    [3395,3498]    [3498,3569]    [3569,3640]    [3640,3761]    [3761,3823]    [3823,3972]    [3972,4040]    [4040,4096]
# Machine 1: job_3_task_0   job_3_task_1   job_3_task_2   job_1_task_2   job_4_task_2   job_7_task_2   job_4_task_4   job_4_task_5   job_4_task_6   job_0_task_8   job_4_task_8   job_6_task_2   job_6_task_3   job_9_task_4   job_5_task_6   job_5_task_7   job_6_task_7   job_0_task_14  job_5_task_10  job_8_task_5   job_8_task_6   job_7_task_13  job_8_task_8   job_5_task_13  job_8_task_10  job_2_task_17  job_1_task_10  job_8_task_12  job_6_task_12  job_1_task_13  job_3_task_11  job_3_task_12  job_8_task_15  job_3_task_14  job_3_task_15  job_1_task_18  job_9_task_17  job_5_task_18  job_8_task_19
#            [0,70]         [70,156]       [156,274]      [275,423]      [429,559]      [559,667]      [708,853]      [853,970]      [970,1062]     [1067,1195]    [1195,1313]    [1313,1364]    [1364,1428]    [1428,1561]    [1561,1655]    [1655,1705]    [1750,1812]    [1945,2021]    [2021,2121]    [2121,2213]    [2213,2312]    [2337,2435]    [2435,2572]    [2572,2660]    [2660,2780]    [2780,2840]    [2840,2905]    [2915,2985]    [2995,3139]    [3139,3221]    [3221,3302]    [3302,3355]    [3402,3461]    [3461,3561]    [3561,3633]    [3633,3712]    [3712,3855]    [3857,3927]    [3973,4050]
# Machine 2: job_2_task_0   job_8_task_0   job_7_task_1   job_5_task_0   job_0_task_2   job_0_task_3   job_1_task_4   job_0_task_5   job_9_task_0   job_2_task_7   job_5_task_2   job_6_task_0   job_6_task_1   job_0_task_10  job_7_task_6   job_6_task_5   job_6_task_6   job_4_task_12  job_2_task_15  job_7_task_9   job_7_task_11  job_0_task_16  job_9_task_9   job_5_task_12  job_3_task_8   job_6_task_10  job_1_task_9   job_5_task_14  job_0_task_18  job_4_task_16  job_5_task_16  job_6_task_13  job_9_task_13  job_3_task_13  job_4_task_19  job_1_task_17  job_2_task_19  job_1_task_19  job_8_task_18  job_9_task_19
#            [0,70]         [71,148]       [149,274]      [274,381]      [381,455]      [455,577]      [577,639]      [683,748]      [748,826]      [826,903]      [903,1047]     [1047,1126]    [1179,1283]    [1283,1427]    [1427,1563]    [1563,1663]    [1663,1718]    [1730,1846]    [1846,1994]    [1994,2104]    [2159,2249]    [2249,2340]    [2340,2420]    [2420,2514]    [2514,2628]    [2640,2762]    [2766,2821]    [2821,2920]    [2920,2973]    [2973,3113]    [3113,3210]    [3210,3264]    [3267,3348]    [3368,3460]    [3460,3561]    [3570,3621]    [3638,3717]    [3732,3851]    [3851,3973]    [3973,4096]
# Machine 3: job_1_task_0   job_0_task_0   job_2_task_1   job_4_task_1   job_2_task_4   job_2_task_5   job_0_task_4   job_1_task_5   job_0_task_6   job_7_task_3   job_9_task_1   job_5_task_3   job_9_task_2   job_9_task_3   job_5_task_5   job_2_task_12  job_9_task_5   job_4_task_11  job_0_task_12  job_8_task_2   job_8_task_3   job_8_task_4   job_7_task_10  job_3_task_6   job_7_task_12  job_5_task_11  job_6_task_8   job_1_task_7   job_8_task_9   job_9_task_10  job_3_task_9   job_3_task_10  job_1_task_11  job_8_task_13  job_9_task_12  job_4_task_18  job_9_task_14  job_9_task_15  job_2_task_18  job_6_task_17  job_3_task_18  job_3_task_19
#            [0,50]         [50,193]       [193,284]      [284,429]      [481,541]      [541,613]      [613,683]      [683,746]      [748,831]      [831,937]      [937,1034]     [1047,1158]    [1158,1292]    [1292,1413]    [1413,1466]    [1468,1559]    [1561,1675]    [1675,1730]    [1730,1854]    [1854,1967]    [1967,2024]    [2024,2102]    [2104,2159]    [2159,2232]    [2249,2337]    [2337,2410]    [2410,2479]    [2479,2558]    [2578,2651]    [2651,2764]    [2764,2822]    [2822,2925]    [2925,3002]    [3002,3149]    [3149,3213]    [3213,3350]    [3350,3438]    [3445,3567]    [3567,3638]    [3688,3805]    [3854,3969]    [3969,4060]
# Machine 4: job_7_task_0   job_8_task_1   job_5_task_1   job_1_task_3   job_4_task_3   job_1_task_6   job_0_task_7   job_2_task_8   job_4_task_7   job_0_task_9   job_2_task_10  job_4_task_9   job_6_task_4   job_2_task_13  job_2_task_14  job_7_task_7   job_0_task_13  job_7_task_8   job_4_task_13  job_9_task_8   job_3_task_7   job_8_task_7   job_7_task_14  job_6_task_9   job_1_task_8   job_8_task_11  job_6_task_11  job_1_task_12  job_0_task_19  job_1_task_14  job_1_task_15  job_6_task_15  job_6_task_16  job_3_task_16  job_3_task_17  job_9_task_18  job_7_task_18  job_6_task_19
#            [0,118]        [157,219]      [381,464]      [464,536]      [560,683]      [746,819]      [831,961]      [961,1108]     [1108,1195]    [1201,1274]    [1274,1331]    [1331,1469]    [1469,1523]    [1559,1662]    [1662,1737]    [1737,1871]    [1871,1942]    [1942,1994]    [1994,2117]    [2117,2254]    [2254,2316]    [2316,2435]    [2435,2564]    [2564,2640]    [2640,2766]    [2780,2900]    [2900,2995]    [3002,3137]    [3137,3275]    [3275,3380]    [3380,3446]    [3446,3522]    [3522,3636]    [3636,3773]    [3773,3854]    [3855,3954]    [3954,4026]    [4026,4095]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 90
#   - wall time: 308.184521s

# %% [markdown]
# # Test for 5 machine, 5 Jobs, each with 24 tasks

# %%
if __name__ == "__main__":

    import random
    random.seed(12345)
    jobs_data = []

    for _ in range(5):
        tmp = []
        for _ in range(24):
            tmp.append((random.randint(0, 4), random.randint(50, 150)))
        jobs_data.append(tmp)
    
    main(jobs_data)
    
    # Optimality?
# Out:
# Solution:
# Optimal Schedule Length: 3449.0
# Machine 0: job_2_task_1   job_0_task_1   job_4_task_1   job_2_task_3   job_2_task_8   job_3_task_8   job_4_task_8   job_1_task_12  job_0_task_11  job_2_task_15  job_2_task_16  job_4_task_12  job_4_task_13  job_1_task_18  job_0_task_15  job_1_task_19  job_0_task_17  job_2_task_17  job_1_task_22  job_4_task_19  job_3_task_18  job_4_task_21  job_0_task_21  job_4_task_23  job_3_task_22  job_3_task_23
#            [149,260]      [268,356]      [356,441]      [441,571]      [1028,1149]    [1149,1207]    [1391,1474]    [1486,1557]    [1564,1681]    [1681,1797]    [1797,1865]    [1865,1918]    [1918,2045]    [2045,2101]    [2101,2175]    [2175,2316]    [2316,2424]    [2424,2558]    [2558,2706]    [2706,2834]    [2860,2943]    [2943,3046]    [3048,3182]    [3182,3250]    [3250,3380]    [3380,3449]
# Machine 1: job_3_task_0   job_3_task_2   job_3_task_3   job_1_task_6   job_1_task_9   job_2_task_9   job_0_task_8   job_2_task_12  job_2_task_13  job_2_task_14  job_1_task_14  job_4_task_10  job_4_task_11  job_3_task_10  job_0_task_14  job_4_task_14  job_3_task_12  job_3_task_13  job_3_task_14  job_4_task_17  job_3_task_16  job_4_task_22  job_0_task_22  job_2_task_23
#            [0,53]         [294,394]      [394,466]      [670,735]      [1006,1088]    [1149,1209]    [1219,1347]    [1359,1429]    [1429,1515]    [1515,1633]    [1633,1712]    [1712,1806]    [1806,1856]    [1856,1986]    [1986,2062]    [2062,2162]    [2162,2307]    [2307,2424]    [2424,2516]    [2516,2604]    [2604,2722]    [3046,3116]    [3182,3330]    [3330,3411]
# Machine 2: job_1_task_0   job_4_task_0   job_3_task_1   job_0_task_2   job_0_task_3   job_1_task_5   job_4_task_3   job_4_task_4   job_0_task_5   job_2_task_7   job_4_task_6   job_2_task_11  job_0_task_10  job_1_task_13  job_1_task_15  job_1_task_16  job_0_task_16  job_4_task_16  job_0_task_18  job_4_task_18  job_2_task_20  job_4_task_20  job_1_task_23  job_3_task_20
#            [0,62]         [62,202]       [202,294]      [356,430]      [430,552]      [552,607]      [607,708]      [708,815]      [815,880]      [880,1028]     [1089,1233]    [1280,1359]    [1420,1564]    [1564,1615]    [1712,1831]    [1831,1901]    [2175,2266]    [2266,2360]    [2424,2477]    [2604,2703]    [2703,2817]    [2834,2931]    [2931,3008]    [3008,3124]
# Machine 3: job_1_task_1   job_0_task_0   job_1_task_3   job_4_task_2   job_2_task_4   job_0_task_4   job_1_task_7   job_3_task_6   job_0_task_6   job_3_task_7   job_2_task_10  job_4_task_7   job_3_task_9   job_4_task_9   job_0_task_12  job_1_task_17  job_4_task_15  job_1_task_20  job_1_task_21  job_2_task_18  job_2_task_21  job_3_task_19  job_0_task_20  job_2_task_22
#            [62,125]       [125,268]      [269,348]      [441,578]      [578,669]      [669,739]      [739,816]      [816,931]      [931,1014]     [1014,1105]    [1209,1280]    [1280,1391]    [1391,1536]    [1536,1589]    [1681,1805]    [1901,1992]    [2162,2235]    [2316,2376]    [2376,2448]    [2558,2631]    [2817,2875]    [2943,2998]    [2998,3048]    [3048,3151]
# Machine 4: job_2_task_0   job_1_task_2   job_2_task_2   job_1_task_4   job_3_task_4   job_3_task_5   job_2_task_5   job_2_task_6   job_1_task_8   job_4_task_5   job_0_task_7   job_1_task_10  job_0_task_9   job_1_task_11  job_0_task_13  job_3_task_11  job_3_task_15  job_2_task_19  job_3_task_17  job_0_task_19  job_3_task_21  job_0_task_23
#            [0,147]        [150,223]      [260,317]      [349,475]      [475,612]      [612,693]      [693,796]      [796,871]      [871,1006]     [1006,1089]    [1089,1219]    [1219,1324]    [1347,1420]    [1420,1486]    [1805,1876]    [1986,2109]    [2516,2603]    [2631,2693]    [2722,2860]    [2860,2998]    [3124,3247]    [3330,3402]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 1
#   - wall time: 41.846156s

# %% [markdown]
# ## Ref and Benchmark
#
# - [JSPLIB](https://github.com/tamy0612/JSPLIB);
# - [FJSP](https://cloud.tencent.com/developer/article/1635976);
# - [FJSP Benchmark](https://github.com/Lei-Kun/FJSP-benchmarks);
# - 现在最主要的研究方向似乎是用强化学习的方法进行求解。[Link](https://mp.weixin.qq.com/s/5TNTEq0jIJvS969LPRMr_Q)
# - 启发式是主要的应用方向。尤其是遗传算法。
