# %%
def readGrid(path):
    with open(f"../assets/data/Str8t/problems/{path}.txt") as f:
        num = f.readline()
        m, n = num.split(" ")[0], num.split(" ")[1]
        grid = f.readlines()
        res = [g.strip().split(" ") for g in grid]
        return int(m), int(n), res

if __name__ == "__main__":
    m, n, grid = readGrid("2_6x6")
    print(m, n)
    print(len(grid), len(grid[0]))
    # print(grid)
    for g in grid:
        print(g)
# Out:
# 6 6
# 6 6
# ['3', '4', 'x', '-', '-', 'x']
# ['-', '-', '1x', '6', '-', 'x']
# ['-', '-', '-', '-', '-', 'x']
# ['x', '-', '-', '-', '1', '-']
# ['x', '-', '3', 'x', '-', '-']
# ['x', '-', '-', 'x', '-', '-']

# %%
from z3 import Solver, Int, Distinct, sat, And, If

def str8t_solver(m, n, grid):
    # every row/column is distinct
    x = []
    grid_nums = grid.copy()
    grid_walls = grid.copy()
    for i in range(m):
        for j in range(n):
            if grid[i][j].isdigit():
                grid_nums[i][j] = int(grid[i][j])
            elif grid[i][j].endswith("x"):
                grid_walls[i][j] = 'x'
                if not grid[i][j].startswith('x'):
                    grid_nums[i][j] = int(grid[i][j][:-1])
                    
    for r in grid_nums:
        print(r)
    for w in grid_walls:
        print(w)
                
    # instance_c = [ If(grid[i][j] == 0, 
    #                 True, 
    #                 X[i][j] == instance[i][j]) 
    #             for i in range(9) for j in range(9) ]

#         x.append(temp)
    
#     range_vars = []
#     for i in range(m):
#         for j in range(n):
#             if grid[i][j] != "x":
#                 range_vars.append(And(1 <= x[i][j], x[i][j] <= 9))

#     print(x)
#     solver = Solver()
#     # for i in range(m):
#     #     temp = []
#     #     for j in range(n):
#     #         if grid[i][j] == 0:
#     #             continue
#     #         # if grid[i][j] == "-":
#     #         temp.append(x[i][j])
#     #     solver.add(Distinct(temp))
#     solver.add(range_vars)
#     # for j in range(n):
#     #     temp = []
#     #     for i in range(m):
#     #         if grid[i][j] == 0:
#     #             continue
#     #         temp.append(x[i][j])
#     #     solver.add(Distinct(temp))
# 9x9 matrix of integer variables
# X = [ [ Int("x_%s_%s" % (i+1, j+1)) for j in range(9) ] 
#       for i in range(9) ]

# # each cell contains a value in {1, ..., 9}
# cells_c  = [ And(1 <= X[i][j], X[i][j] <= 9) 
#              for i in range(9) for j in range(9) ]

# # each row contains a digit at most once
# rows_c   = [ Distinct(X[i]) for i in range(9) ]

# # each column contains a digit at most once
# cols_c   = [ Distinct([ X[i][j] for i in range(9) ]) 
#              for j in range(9) ]

# # each 3x3 square contains a digit at most once
# sq_c     = [ Distinct([ X[3*i0 + i][3*j0 + j] 
#                         for i in range(3) for j in range(3) ]) 
#              for i0 in range(3) for j0 in range(3) ]

# sudoku_c = cells_c + rows_c + cols_c + sq_c

# # sudoku instance, we use '0' for empty cells
# instance = ((0,0,0,0,9,4,0,3,0),
#             (0,0,0,5,1,0,0,0,7),
#             (0,8,9,0,0,0,0,4,0),
#             (0,0,0,0,0,0,2,0,8),
#             (0,6,0,2,0,1,0,5,0),
#             (1,0,2,0,0,0,0,0,0),
#             (0,7,0,0,0,0,5,2,0),
#             (9,0,0,0,6,5,0,0,0),
#             (0,4,0,9,7,0,0,0,0))

# instance_c = [ If(instance[i][j] == 0, 
#                   True, 
#                   X[i][j] == instance[i][j]) 
#                for i in range(9) for j in range(9) ]

# s = Solver()
# s.add(sudoku_c + instance_c)
# if s.check() == sat:
#     m = s.model()
#     r = [ [ m.evaluate(X[i][j]) for j in range(9) ] 
#           for i in range(9) ]
#     for k in r:
#         print(k)
# else:
#     print ("failed to solve")
    
    
# def str8t_solver(m, n, grid):
#     # every row/column is distinct
#     x = []
#     for i in range(m):
#         temp = []
#         for j in range(n):
#             if grid[i][j] in ['-']:
#                 temp.append(Int(f"x_{i}_{j}"))
#             elif grid[i][j].endswith("x") and grid[i][j].startswith("x"):
#                 temp.append(0)
#             else:
#                 temp.append(Int(f"x_{i}_{j}"))

#         x.append(temp)
    
#     range_vars = []
#     for i in range(m):
#         for j in range(n):
#             if grid[i][j] != "x":
#                 range_vars.append(And(1 <= x[i][j], x[i][j] <= 9))

#     print(x)
#     solver = Solver()
#     # for i in range(m):
#     #     temp = []
#     #     for j in range(n):
#     #         if grid[i][j] == 0:
#     #             continue
#     #         # if grid[i][j] == "-":
#     #         temp.append(x[i][j])
#     #     solver.add(Distinct(temp))
#     solver.add(range_vars)
#     # for j in range(n):
#     #     temp = []
#     #     for i in range(m):
#     #         if grid[i][j] == 0:
#     #             continue
#     #         temp.append(x[i][j])
#     #     solver.add(Distinct(temp))
    
#     if solver.check() == sat:
#         print("A>")
#         model = solver.model()
#         r = [ [ model.evaluate(x[i][j]) for j in range(n) ] 
#           for i in range(m) ]
#         # solution = [[model.eval(grid[i][j]).as_long() for j in range(n)] for i in range(m)]
#         for row in r:
#             print(row)
#     else:
#         print("No solution exists")
#     # # 定义网格大小和变量
#     # N = 5  # 网格大小
#     # grid = [[Int(f"x_{i}_{j}") for j in range(N)] for i in range(N)]

#     # solver = Solver()

#     # # 约束1：每个格子的值在1到N之间
#     # for i in range(N):
#     #     for j in range(N):
#     #         solver.add(grid[i][j] >= 1, grid[i][j] <= N)

#     # # 约束2：每行每列的值不重复
#     # for i in range(N):
#     #     solver.add(Distinct(grid[i]))  # 行约束
#     #     solver.add(Distinct([grid[j][i] for j in range(N)]))  # 列约束

#     # # 约束3：定义连续的4个格子构成一个连续数字的集合
#     # # 例如，假设选择第一行的前4个格子
#     # selected_cells = [grid[0][j] for j in range(4)]  # 选定连续的4个格子
#     # solver.add(max(selected_cells) - min(selected_cells) == 3)  # 最大值和最小值之差为3
#     # solver.add(Distinct(selected_cells))  # 值互不相同

#     # # 检查是否可满足，并输出结果
#     # if solver.check() == 'sat':
#     #     model = solver.model()
#     #     solution = [[model.eval(grid[i][j]).as_long() for j in range(N)] for i in range(N)]
#     #     for row in solution:
#     #         print(row)
#     # else:
#     #     print("No solution exists")

if __name__ == "__main__":
    str8t_solver(m, n, grid)
# Out:
# [3, 4, 'x', '-', '-', 'x']
# ['-', '-', 'x', 6, '-', 'x']
# ['-', '-', '-', '-', '-', 'x']
# ['x', '-', '-', '-', 1, '-']
# ['x', '-', 3, 'x', '-', '-']
# ['x', '-', '-', 'x', '-', '-']
# [3, 4, 'x', '-', '-', 'x']
# ['-', '-', 'x', 6, '-', 'x']
# ['-', '-', '-', '-', '-', 'x']
# ['x', '-', '-', '-', 1, '-']
# ['x', '-', 3, 'x', '-', '-']
# ['x', '-', '-', 'x', '-', '-']
