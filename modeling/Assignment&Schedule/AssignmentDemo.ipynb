# %% [markdown]
# ## Assignment with Team workers
#
# 分配问题有许多版本，它们对工作程序或任务有额外的约束。下面的代码里，500个工作程序被划分为两个团队（分别300个人），每个团队最多可以执行250个任务。

# %%
"""MIP example that solves an assignment problem."""
from ortools.linear_solver import pywraplp
import random

def main():
    # Data
    random.seed(2025)
    num_of_tasks = 500
    num_of_workers = 600
    cost_random = [random.randint(100, 2000) for _ in range(num_of_tasks * num_of_workers)]
    costs = [
        cost_random[idx * num_of_tasks: (idx + 1) * num_of_tasks] for idx in range(num_of_workers)
    ]
    num_workers = len(costs)
    num_tasks = len(costs[0])

    team1 = [i for i in range(0, num_of_workers, 2)]
    team2 = [i for i in range(1, num_of_workers, 2)]
    # Maximum total of tasks for any team
    team_max = num_of_tasks // 2

    # Solver
    # Create the mip solver with the SCIP backend.
    solver = pywraplp.Solver.CreateSolver("SCIP")
    if not solver:
        return

    # Variables
    # x[i, j] is an array of 0-1 variables, which will be 1
    # if worker i is assigned to task j.
    x = {}
    for worker in range(num_workers):
        for task in range(num_tasks):
            x[worker, task] = solver.BoolVar(f"x[{worker},{task}]")

    # Constraints
    # Each worker is assigned at most 1 task.
    for worker in range(num_workers):
        solver.Add(solver.Sum([x[worker, task] for task in range(num_tasks)]) <= 1)

    # Each task is assigned to exactly one worker.
    for task in range(num_tasks):
        solver.Add(solver.Sum([x[worker, task] for worker in range(num_workers)]) == 1)

    # Each team takes at most two tasks.
    team1_tasks = []
    for worker in team1:
        for task in range(num_tasks):
            team1_tasks.append(x[worker, task])
    solver.Add(solver.Sum(team1_tasks) <= team_max)

    team2_tasks = []
    for worker in team2:
        for task in range(num_tasks):
            team2_tasks.append(x[worker, task])
    solver.Add(solver.Sum(team2_tasks) <= team_max)

    # Objective
    objective_terms = []
    for worker in range(num_workers):
        for task in range(num_tasks):
            objective_terms.append(costs[worker][task] * x[worker, task])
    solver.Minimize(solver.Sum(objective_terms))

    # Solve
    print(f"Solving with {solver.SolverVersion()}")
    status = solver.Solve()

    # Print solution.
    if status == pywraplp.Solver.OPTIMAL or status == pywraplp.Solver.FEASIBLE:
        print(f"Total cost = {solver.Objective().Value()}\n")
        for worker in range(num_workers):
            for task in range(num_tasks):
                if x[worker, task].solution_value() > 0.5:
                    print(
                        f"Worker {worker} assigned to task {task}."
                        + f" Cost = {costs[worker][task]}"
                    )
    else:
        print("No solution found.")
    print(f"Time = {solver.WallTime()} ms")


if __name__ == "__main__":
    main()
# Out:
# Solving with SCIP 9.0.0 [LP solver: Glop 9.10]
# Total cost = 51980.00000000001
#
# Worker 0 assigned to task 7. Cost = 100
# Worker 1 assigned to task 470. Cost = 106
# Worker 2 assigned to task 260. Cost = 100
# Worker 3 assigned to task 385. Cost = 101
# Worker 4 assigned to task 0. Cost = 102
# Worker 6 assigned to task 70. Cost = 101
# Worker 7 assigned to task 44. Cost = 118
# Worker 8 assigned to task 292. Cost = 100
# Worker 9 assigned to task 482. Cost = 100
# Worker 10 assigned to task 12. Cost = 107
# Worker 11 assigned to task 229. Cost = 100
# Worker 12 assigned to task 100. Cost = 107
# Worker 13 assigned to task 170. Cost = 117
# Worker 14 assigned to task 42. Cost = 101
# Worker 15 assigned to task 164. Cost = 100
# Worker 16 assigned to task 368. Cost = 101
# Worker 17 assigned to task 197. Cost = 111
# Worker 18 assigned to task 31. Cost = 105
# Worker 19 assigned to task 309. Cost = 104
# Worker 20 assigned to task 139. Cost = 101
# Worker 21 assigned to task 354. Cost = 106
# Worker 22 assigned to task 464. Cost = 104
# Worker 23 assigned to task 356. Cost = 103
# Worker 25 assigned to task 36. Cost = 102
# Worker 26 assigned to task 366. Cost = 106
# Worker 27 assigned to task 421. Cost = 101
# Worker 28 assigned to task 340. Cost = 106
# Worker 29 assigned to task 253. Cost = 103
# Worker 30 assigned to task 137. Cost = 104
# Worker 31 assigned to task 107. Cost = 101
# Worker 32 assigned to task 29. Cost = 102
# Worker 33 assigned to task 194. Cost = 101
# Worker 34 assigned to task 57. Cost = 100
# Worker 35 assigned to task 267. Cost = 108
# Worker 36 assigned to task 244. Cost = 106
# Worker 38 assigned to task 58. Cost = 103
# Worker 39 assigned to task 221. Cost = 103
# Worker 40 assigned to task 143. Cost = 102
# Worker 41 assigned to task 341. Cost = 100
# Worker 42 assigned to task 355. Cost = 103
# Worker 43 assigned to task 270. Cost = 101
# Worker 44 assigned to task 226. Cost = 109
# Worker 45 assigned to task 232. Cost = 106
# Worker 46 assigned to task 463. Cost = 104
# Worker 47 assigned to task 2. Cost = 101
# Worker 48 assigned to task 156. Cost = 102
# Worker 50 assigned to task 74. Cost = 112
# Worker 51 assigned to task 380. Cost = 100
# Worker 52 assigned to task 351. Cost = 100
# Worker 53 assigned to task 223. Cost = 106
# Worker 54 assigned to task 271. Cost = 102
# Worker 55 assigned to task 360. Cost = 114
# Worker 56 assigned to task 141. Cost = 101
# Worker 58 assigned to task 447. Cost = 103
# Worker 59 assigned to task 481. Cost = 103
# Worker 60 assigned to task 129. Cost = 101
# Worker 62 assigned to task 201. Cost = 102
# Worker 63 assigned to task 465. Cost = 101
# Worker 64 assigned to task 30. Cost = 101
# Worker 65 assigned to task 180. Cost = 101
# Worker 66 assigned to task 345. Cost = 100
# Worker 67 assigned to task 396. Cost = 110
# Worker 68 assigned to task 187. Cost = 107
# Worker 69 assigned to task 199. Cost = 114
# Worker 70 assigned to task 412. Cost = 100
# Worker 71 assigned to task 322. Cost = 102
# Worker 72 assigned to task 145. Cost = 103
# Worker 73 assigned to task 92. Cost = 103
# Worker 75 assigned to task 489. Cost = 104
# Worker 76 assigned to task 479. Cost = 109
# Worker 77 assigned to task 473. Cost = 100
# Worker 78 assigned to task 374. Cost = 100
# Worker 79 assigned to task 214. Cost = 103
# Worker 80 assigned to task 275. Cost = 104
# Worker 82 assigned to task 33. Cost = 102
# Worker 83 assigned to task 371. Cost = 101
# Worker 84 assigned to task 54. Cost = 107
# Worker 85 assigned to task 48. Cost = 102
# Worker 86 assigned to task 325. Cost = 112
# Worker 87 assigned to task 414. Cost = 103
# Worker 89 assigned to task 282. Cost = 100
# Worker 90 assigned to task 415. Cost = 102
# Worker 91 assigned to task 93. Cost = 102
# Worker 92 assigned to task 101. Cost = 109
# Worker 93 assigned to task 391. Cost = 101
# Worker 95 assigned to task 301. Cost = 120
# Worker 96 assigned to task 444. Cost = 102
# Worker 97 assigned to task 215. Cost = 100
# Worker 98 assigned to task 434. Cost = 103
# Worker 99 assigned to task 246. Cost = 100
# Worker 100 assigned to task 192. Cost = 102
# Worker 104 assigned to task 299. Cost = 100
# Worker 105 assigned to task 329. Cost = 101
# Worker 107 assigned to task 446. Cost = 101
# Worker 109 assigned to task 422. Cost = 102
# Worker 110 assigned to task 150. Cost = 101
# Worker 111 assigned to task 125. Cost = 101
# Worker 112 assigned to task 91. Cost = 108
# Worker 113 assigned to task 165. Cost = 105
# Worker 114 assigned to task 370. Cost = 103
# Worker 115 assigned to task 274. Cost = 100
# Worker 117 assigned to task 1. Cost = 116
# Worker 119 assigned to task 403. Cost = 105
# Worker 121 assigned to task 195. Cost = 114
# Worker 123 assigned to task 218. Cost = 107
# Worker 125 assigned to task 59. Cost = 105
# Worker 126 assigned to task 69. Cost = 104
# Worker 127 assigned to task 499. Cost = 101
# Worker 129 assigned to task 198. Cost = 102
# Worker 131 assigned to task 168. Cost = 100
# Worker 133 assigned to task 480. Cost = 102
# Worker 134 assigned to task 149. Cost = 107
# Worker 135 assigned to task 154. Cost = 116
# Worker 136 assigned to task 11. Cost = 111
# Worker 138 assigned to task 410. Cost = 106
# Worker 139 assigned to task 15. Cost = 102
# Worker 140 assigned to task 32. Cost = 105
# Worker 141 assigned to task 45. Cost = 101
# Worker 142 assigned to task 98. Cost = 102
# Worker 144 assigned to task 435. Cost = 106
# Worker 147 assigned to task 68. Cost = 100
# Worker 148 assigned to task 468. Cost = 104
# Worker 149 assigned to task 249. Cost = 101
# Worker 150 assigned to task 89. Cost = 102
# Worker 151 assigned to task 151. Cost = 109
# Worker 152 assigned to task 38. Cost = 100
# Worker 153 assigned to task 399. Cost = 102
# Worker 154 assigned to task 47. Cost = 102
# Worker 155 assigned to task 9. Cost = 101
# Worker 157 assigned to task 203. Cost = 107
# Worker 160 assigned to task 184. Cost = 100
# Worker 161 assigned to task 304. Cost = 109
# Worker 162 assigned to task 136. Cost = 107
# Worker 164 assigned to task 456. Cost = 101
# Worker 165 assigned to task 287. Cost = 109
# Worker 166 assigned to task 10. Cost = 101
# Worker 170 assigned to task 256. Cost = 102
# Worker 171 assigned to task 490. Cost = 125
# Worker 174 assigned to task 75. Cost = 101
# Worker 175 assigned to task 166. Cost = 101
# Worker 177 assigned to task 472. Cost = 101
# Worker 178 assigned to task 140. Cost = 102
# Worker 180 assigned to task 264. Cost = 103
# Worker 181 assigned to task 423. Cost = 101
# Worker 182 assigned to task 217. Cost = 104
# Worker 183 assigned to task 401. Cost = 100
# Worker 184 assigned to task 202. Cost = 102
# Worker 186 assigned to task 27. Cost = 104
# Worker 187 assigned to task 432. Cost = 105
# Worker 188 assigned to task 77. Cost = 101
# Worker 190 assigned to task 238. Cost = 109
# Worker 192 assigned to task 3. Cost = 108
# Worker 193 assigned to task 196. Cost = 110
# Worker 194 assigned to task 429. Cost = 117
# Worker 195 assigned to task 176. Cost = 104
# Worker 197 assigned to task 409. Cost = 102
# Worker 198 assigned to task 236. Cost = 104
# Worker 199 assigned to task 343. Cost = 103
# Worker 200 assigned to task 4. Cost = 102
# Worker 201 assigned to task 394. Cost = 102
# Worker 202 assigned to task 122. Cost = 110
# Worker 203 assigned to task 28. Cost = 100
# Worker 204 assigned to task 439. Cost = 104
# Worker 205 assigned to task 133. Cost = 103
# Worker 206 assigned to task 153. Cost = 102
# Worker 207 assigned to task 320. Cost = 102
# Worker 208 assigned to task 46. Cost = 104
# Worker 209 assigned to task 315. Cost = 109
# Worker 210 assigned to task 23. Cost = 101
# Worker 211 assigned to task 5. Cost = 109
# Worker 212 assigned to task 174. Cost = 106
# Worker 214 assigned to task 55. Cost = 101
# Worker 215 assigned to task 323. Cost = 103
# Worker 216 assigned to task 308. Cost = 107
# Worker 218 assigned to task 169. Cost = 105
# Worker 219 assigned to task 67. Cost = 101
# Worker 220 assigned to task 487. Cost = 103
# Worker 221 assigned to task 85. Cost = 101
# Worker 222 assigned to task 377. Cost = 104
# Worker 223 assigned to task 418. Cost = 104
# Worker 224 assigned to task 130. Cost = 107
# Worker 226 assigned to task 316. Cost = 100
# Worker 227 assigned to task 24. Cost = 101
# Worker 228 assigned to task 152. Cost = 101
# Worker 229 assigned to task 381. Cost = 109
# Worker 230 assigned to task 376. Cost = 102
# Worker 231 assigned to task 278. Cost = 102
# Worker 232 assigned to task 183. Cost = 100
# Worker 233 assigned to task 63. Cost = 108
# Worker 234 assigned to task 367. Cost = 100
# Worker 235 assigned to task 404. Cost = 100
# Worker 236 assigned to task 213. Cost = 108
# Worker 237 assigned to task 111. Cost = 103
# Worker 238 assigned to task 78. Cost = 111
# Worker 240 assigned to task 452. Cost = 100
# Worker 241 assigned to task 347. Cost = 103
# Worker 242 assigned to task 80. Cost = 103
# Worker 243 assigned to task 333. Cost = 100
# Worker 244 assigned to task 88. Cost = 101
# Worker 245 assigned to task 277. Cost = 107
# Worker 247 assigned to task 298. Cost = 104
# Worker 248 assigned to task 349. Cost = 103
# Worker 250 assigned to task 339. Cost = 100
# Worker 251 assigned to task 84. Cost = 104
# Worker 252 assigned to task 492. Cost = 101
# Worker 253 assigned to task 186. Cost = 101
# Worker 254 assigned to task 408. Cost = 101
# Worker 255 assigned to task 49. Cost = 110
# Worker 256 assigned to task 455. Cost = 104
# Worker 257 assigned to task 51. Cost = 101
# Worker 258 assigned to task 307. Cost = 104
# Worker 259 assigned to task 134. Cost = 100
# Worker 260 assigned to task 158. Cost = 108
# Worker 262 assigned to task 344. Cost = 102
# Worker 263 assigned to task 109. Cost = 102
# Worker 264 assigned to task 17. Cost = 106
# Worker 265 assigned to task 182. Cost = 100
# Worker 267 assigned to task 369. Cost = 105
# Worker 268 assigned to task 372. Cost = 106
# Worker 269 assigned to task 342. Cost = 100
# Worker 270 assigned to task 448. Cost = 106
# Worker 271 assigned to task 212. Cost = 110
# Worker 272 assigned to task 132. Cost = 100
# Worker 273 assigned to task 72. Cost = 100
# Worker 274 assigned to task 373. Cost = 107
# Worker 275 assigned to task 337. Cost = 101
# Worker 276 assigned to task 16. Cost = 102
# Worker 278 assigned to task 83. Cost = 100
# Worker 279 assigned to task 324. Cost = 103
# Worker 280 assigned to task 207. Cost = 102
# Worker 282 assigned to task 477. Cost = 105
# Worker 283 assigned to task 190. Cost = 107
# Worker 284 assigned to task 220. Cost = 100
# Worker 285 assigned to task 387. Cost = 104
# Worker 286 assigned to task 239. Cost = 107
# Worker 287 assigned to task 272. Cost = 106
# Worker 288 assigned to task 208. Cost = 108
# Worker 289 assigned to task 161. Cost = 102
# Worker 290 assigned to task 108. Cost = 102
# Worker 291 assigned to task 290. Cost = 104
# Worker 292 assigned to task 348. Cost = 100
# Worker 293 assigned to task 419. Cost = 109
# Worker 294 assigned to task 205. Cost = 113
# Worker 295 assigned to task 193. Cost = 101
# Worker 296 assigned to task 288. Cost = 102
# Worker 297 assigned to task 115. Cost = 101
# Worker 298 assigned to task 172. Cost = 103
# Worker 300 assigned to task 252. Cost = 105
# Worker 301 assigned to task 346. Cost = 101
# Worker 302 assigned to task 178. Cost = 106
# Worker 303 assigned to task 352. Cost = 103
# Worker 304 assigned to task 225. Cost = 104
# Worker 305 assigned to task 321. Cost = 101
# Worker 306 assigned to task 185. Cost = 100
# Worker 307 assigned to task 285. Cost = 108
# Worker 308 assigned to task 379. Cost = 107
# Worker 309 assigned to task 243. Cost = 108
# Worker 310 assigned to task 216. Cost = 101
# Worker 311 assigned to task 258. Cost = 102
# Worker 312 assigned to task 228. Cost = 101
# Worker 313 assigned to task 102. Cost = 104
# Worker 315 assigned to task 234. Cost = 104
# Worker 316 assigned to task 406. Cost = 101
# Worker 317 assigned to task 392. Cost = 103
# Worker 318 assigned to task 330. Cost = 100
# Worker 319 assigned to task 313. Cost = 100
# Worker 320 assigned to task 291. Cost = 104
# Worker 321 assigned to task 293. Cost = 107
# Worker 323 assigned to task 250. Cost = 103
# Worker 324 assigned to task 407. Cost = 107
# Worker 325 assigned to task 179. Cost = 102
# Worker 326 assigned to task 364. Cost = 105
# Worker 327 assigned to task 485. Cost = 108
# Worker 328 assigned to task 402. Cost = 106
# Worker 329 assigned to task 405. Cost = 103
# Worker 330 assigned to task 335. Cost = 106
# Worker 331 assigned to task 237. Cost = 102
# Worker 332 assigned to task 188. Cost = 106
# Worker 333 assigned to task 159. Cost = 107
# Worker 334 assigned to task 171. Cost = 102
# Worker 335 assigned to task 60. Cost = 104
# Worker 336 assigned to task 62. Cost = 106
# Worker 337 assigned to task 268. Cost = 103
# Worker 339 assigned to task 41. Cost = 108
# Worker 341 assigned to task 97. Cost = 108
# Worker 344 assigned to task 493. Cost = 109
# Worker 345 assigned to task 247. Cost = 104
# Worker 346 assigned to task 227. Cost = 102
# Worker 348 assigned to task 173. Cost = 110
# Worker 349 assigned to task 497. Cost = 109
# Worker 350 assigned to task 436. Cost = 101
# Worker 351 assigned to task 189. Cost = 117
# Worker 352 assigned to task 427. Cost = 111
# Worker 353 assigned to task 21. Cost = 104
# Worker 354 assigned to task 440. Cost = 101
# Worker 355 assigned to task 496. Cost = 100
# Worker 357 assigned to task 121. Cost = 101
# Worker 359 assigned to task 233. Cost = 107
# Worker 360 assigned to task 123. Cost = 108
# Worker 361 assigned to task 450. Cost = 101
# Worker 362 assigned to task 79. Cost = 105
# Worker 363 assigned to task 266. Cost = 100
# Worker 364 assigned to task 459. Cost = 107
# Worker 365 assigned to task 112. Cost = 101
# Worker 366 assigned to task 71. Cost = 102
# Worker 367 assigned to task 457. Cost = 106
# Worker 368 assigned to task 289. Cost = 107
# Worker 369 assigned to task 120. Cost = 101
# Worker 370 assigned to task 458. Cost = 102
# Worker 371 assigned to task 163. Cost = 103
# Worker 372 assigned to task 428. Cost = 100
# Worker 373 assigned to task 296. Cost = 103
# Worker 374 assigned to task 103. Cost = 103
# Worker 376 assigned to task 26. Cost = 101
# Worker 377 assigned to task 453. Cost = 102
# Worker 381 assigned to task 386. Cost = 107
# Worker 382 assigned to task 382. Cost = 101
# Worker 383 assigned to task 462. Cost = 101
# Worker 384 assigned to task 265. Cost = 102
# Worker 385 assigned to task 240. Cost = 100
# Worker 386 assigned to task 155. Cost = 109
# Worker 387 assigned to task 449. Cost = 104
# Worker 391 assigned to task 398. Cost = 102
# Worker 392 assigned to task 416. Cost = 100
# Worker 393 assigned to task 8. Cost = 101
# Worker 394 assigned to task 116. Cost = 102
# Worker 395 assigned to task 241. Cost = 117
# Worker 396 assigned to task 276. Cost = 100
# Worker 398 assigned to task 359. Cost = 100
# Worker 399 assigned to task 273. Cost = 110
# Worker 400 assigned to task 389. Cost = 103
# Worker 401 assigned to task 53. Cost = 104
# Worker 402 assigned to task 460. Cost = 100
# Worker 403 assigned to task 424. Cost = 102
# Worker 407 assigned to task 466. Cost = 109
# Worker 408 assigned to task 488. Cost = 102
# Worker 409 assigned to task 177. Cost = 101
# Worker 410 assigned to task 336. Cost = 101
# Worker 411 assigned to task 467. Cost = 101
# Worker 412 assigned to task 294. Cost = 107
# Worker 413 assigned to task 104. Cost = 105
# Worker 414 assigned to task 433. Cost = 103
# Worker 415 assigned to task 114. Cost = 101
# Worker 416 assigned to task 13. Cost = 109
# Worker 417 assigned to task 254. Cost = 107
# Worker 418 assigned to task 411. Cost = 103
# Worker 419 assigned to task 327. Cost = 109
# Worker 420 assigned to task 25. Cost = 102
# Worker 421 assigned to task 328. Cost = 103
# Worker 422 assigned to task 498. Cost = 100
# Worker 423 assigned to task 66. Cost = 102
# Worker 424 assigned to task 106. Cost = 101
# Worker 425 assigned to task 52. Cost = 101
# Worker 426 assigned to task 90. Cost = 109
# Worker 427 assigned to task 20. Cost = 109
# Worker 428 assigned to task 81. Cost = 106
# Worker 429 assigned to task 118. Cost = 105
# Worker 430 assigned to task 400. Cost = 103
# Worker 431 assigned to task 319. Cost = 105
# Worker 433 assigned to task 383. Cost = 102
# Worker 434 assigned to task 94. Cost = 105
# Worker 435 assigned to task 281. Cost = 107
# Worker 436 assigned to task 283. Cost = 102
# Worker 438 assigned to task 64. Cost = 100
# Worker 439 assigned to task 34. Cost = 103
# Worker 440 assigned to task 474. Cost = 107
# Worker 441 assigned to task 317. Cost = 103
# Worker 443 assigned to task 99. Cost = 101
# Worker 444 assigned to task 135. Cost = 103
# Worker 445 assigned to task 61. Cost = 102
# Worker 448 assigned to task 148. Cost = 101
# Worker 450 assigned to task 384. Cost = 100
# Worker 451 assigned to task 279. Cost = 102
# Worker 452 assigned to task 209. Cost = 101
# Worker 454 assigned to task 437. Cost = 102
# Worker 455 assigned to task 331. Cost = 101
# Worker 456 assigned to task 295. Cost = 110
# Worker 457 assigned to task 357. Cost = 101
# Worker 458 assigned to task 95. Cost = 111
# Worker 460 assigned to task 302. Cost = 101
# Worker 461 assigned to task 210. Cost = 109
# Worker 462 assigned to task 162. Cost = 100
# Worker 463 assigned to task 261. Cost = 100
# Worker 465 assigned to task 128. Cost = 107
# Worker 466 assigned to task 124. Cost = 100
# Worker 467 assigned to task 50. Cost = 101
# Worker 468 assigned to task 19. Cost = 103
# Worker 469 assigned to task 242. Cost = 122
# Worker 470 assigned to task 76. Cost = 105
# Worker 471 assigned to task 14. Cost = 104
# Worker 472 assigned to task 43. Cost = 104
# Worker 473 assigned to task 37. Cost = 102
# Worker 474 assigned to task 441. Cost = 100
# Worker 476 assigned to task 365. Cost = 109
# Worker 478 assigned to task 126. Cost = 101
# Worker 479 assigned to task 314. Cost = 104
# Worker 480 assigned to task 483. Cost = 105
# Worker 481 assigned to task 131. Cost = 103
# Worker 482 assigned to task 390. Cost = 115
# Worker 483 assigned to task 461. Cost = 103
# Worker 484 assigned to task 204. Cost = 100
# Worker 485 assigned to task 303. Cost = 100
# Worker 486 assigned to task 395. Cost = 109
# Worker 488 assigned to task 454. Cost = 110
# Worker 489 assigned to task 40. Cost = 107
# Worker 491 assigned to task 86. Cost = 105
# Worker 492 assigned to task 65. Cost = 109
# Worker 495 assigned to task 87. Cost = 101
# Worker 496 assigned to task 397. Cost = 106
# Worker 497 assigned to task 363. Cost = 106
# Worker 498 assigned to task 478. Cost = 100
# Worker 499 assigned to task 451. Cost = 106
# Worker 500 assigned to task 388. Cost = 100
# Worker 501 assigned to task 235. Cost = 101
# Worker 502 assigned to task 82. Cost = 112
# Worker 503 assigned to task 476. Cost = 101
# Worker 504 assigned to task 6. Cost = 106
# Worker 505 assigned to task 138. Cost = 101
# Worker 507 assigned to task 300. Cost = 102
# Worker 508 assigned to task 96. Cost = 102
# Worker 509 assigned to task 35. Cost = 100
# Worker 510 assigned to task 358. Cost = 103
# Worker 511 assigned to task 326. Cost = 107
# Worker 512 assigned to task 119. Cost = 102
# Worker 513 assigned to task 248. Cost = 101
# Worker 515 assigned to task 222. Cost = 106
# Worker 517 assigned to task 144. Cost = 100
# Worker 518 assigned to task 191. Cost = 104
# Worker 521 assigned to task 167. Cost = 104
# Worker 522 assigned to task 361. Cost = 100
# Worker 523 assigned to task 334. Cost = 104
# Worker 524 assigned to task 127. Cost = 101
# Worker 525 assigned to task 438. Cost = 101
# Worker 526 assigned to task 219. Cost = 105
# Worker 528 assigned to task 350. Cost = 100
# Worker 529 assigned to task 431. Cost = 100
# Worker 530 assigned to task 105. Cost = 102
# Worker 532 assigned to task 475. Cost = 100
# Worker 533 assigned to task 284. Cost = 108
# Worker 534 assigned to task 318. Cost = 102
# Worker 535 assigned to task 495. Cost = 105
# Worker 536 assigned to task 39. Cost = 115
# Worker 537 assigned to task 117. Cost = 103
# Worker 538 assigned to task 211. Cost = 104
# Worker 539 assigned to task 259. Cost = 100
# Worker 540 assigned to task 231. Cost = 108
# Worker 541 assigned to task 393. Cost = 104
# Worker 542 assigned to task 18. Cost = 103
# Worker 543 assigned to task 206. Cost = 104
# Worker 544 assigned to task 310. Cost = 102
# Worker 545 assigned to task 491. Cost = 109
# Worker 546 assigned to task 262. Cost = 105
# Worker 547 assigned to task 425. Cost = 101
# Worker 548 assigned to task 445. Cost = 101
# Worker 549 assigned to task 255. Cost = 102
# Worker 550 assigned to task 56. Cost = 110
# Worker 552 assigned to task 160. Cost = 102
# Worker 553 assigned to task 142. Cost = 104
# Worker 554 assigned to task 305. Cost = 103
# Worker 555 assigned to task 443. Cost = 103
# Worker 556 assigned to task 286. Cost = 100
# Worker 557 assigned to task 417. Cost = 101
# Worker 558 assigned to task 486. Cost = 116
# Worker 559 assigned to task 442. Cost = 107
# Worker 561 assigned to task 157. Cost = 102
# Worker 562 assigned to task 378. Cost = 109
# Worker 563 assigned to task 413. Cost = 102
# Worker 564 assigned to task 426. Cost = 105
# Worker 567 assigned to task 263. Cost = 105
# Worker 568 assigned to task 181. Cost = 105
# Worker 569 assigned to task 430. Cost = 100
# Worker 571 assigned to task 332. Cost = 110
# Worker 572 assigned to task 269. Cost = 103
# Worker 573 assigned to task 251. Cost = 113
# Worker 574 assigned to task 22. Cost = 100
# Worker 575 assigned to task 257. Cost = 100
# Worker 576 assigned to task 420. Cost = 101
# Worker 577 assigned to task 306. Cost = 100
# Worker 578 assigned to task 280. Cost = 100
# Worker 579 assigned to task 311. Cost = 101
# Worker 580 assigned to task 146. Cost = 118
# Worker 581 assigned to task 484. Cost = 103
# Worker 582 assigned to task 375. Cost = 103
# Worker 583 assigned to task 494. Cost = 107
# Worker 584 assigned to task 245. Cost = 101
# Worker 585 assigned to task 230. Cost = 111
# Worker 586 assigned to task 353. Cost = 105
# Worker 587 assigned to task 73. Cost = 102
# Worker 588 assigned to task 312. Cost = 109
# Worker 589 assigned to task 297. Cost = 111
# Worker 590 assigned to task 113. Cost = 106
# Worker 591 assigned to task 469. Cost = 101
# Worker 592 assigned to task 471. Cost = 102
# Worker 593 assigned to task 147. Cost = 100
# Worker 594 assigned to task 362. Cost = 104
# Worker 595 assigned to task 110. Cost = 101
# Worker 596 assigned to task 175. Cost = 103
# Worker 597 assigned to task 338. Cost = 107
# Worker 598 assigned to task 200. Cost = 100
# Worker 599 assigned to task 224. Cost = 112
# Time = 37282 ms

# %% [markdown]
# ## Assignment with Task size

# %%
"""MIP example that solves an assignment problem."""
from ortools.linear_solver import pywraplp


def main():
    # Data
    costs = [
        [90, 76, 75, 70, 50, 74, 12, 68],
        [35, 85, 55, 65, 48, 101, 70, 83],
        [125, 95, 90, 105, 59, 120, 36, 73],
        [45, 110, 95, 115, 104, 83, 37, 71],
        [60, 105, 80, 75, 59, 62, 93, 88],
        [45, 65, 110, 95, 47, 31, 81, 34],
        [38, 51, 107, 41, 69, 99, 115, 48],
        [47, 85, 57, 71, 92, 77, 109, 36],
        [39, 63, 97, 49, 118, 56, 92, 61],
        [47, 101, 71, 60, 88, 109, 52, 90],
    ]
    num_workers = len(costs)
    num_tasks = len(costs[0])

    task_sizes = [10, 7, 3, 12, 15, 4, 11, 5]
    # Maximum total of task sizes for any worker
    total_size_max = 15

    # Solver
    # Create the mip solver with the SCIP backend.
    solver = pywraplp.Solver.CreateSolver("SCIP")

    if not solver:
        return

    # Variables
    # x[i, j] is an array of 0-1 variables, which will be 1
    # if worker i is assigned to task j.
    x = {}
    for worker in range(num_workers):
        for task in range(num_tasks):
            x[worker, task] = solver.BoolVar(f"x[{worker},{task}]")

    # Constraints
    # The total size of the tasks each worker takes on is at most total_size_max.
    for worker in range(num_workers):
        solver.Add(
            solver.Sum(
                [task_sizes[task] * x[worker, task] for task in range(num_tasks)]
            )
            <= total_size_max
        )

    # Each task is assigned to exactly one worker.
    for task in range(num_tasks):
        solver.Add(solver.Sum([x[worker, task] for worker in range(num_workers)]) == 1)

    # Objective
    objective_terms = []
    for worker in range(num_workers):
        for task in range(num_tasks):
            objective_terms.append(costs[worker][task] * x[worker, task])
    solver.Minimize(solver.Sum(objective_terms))

    # Solve
    print(f"Solving with {solver.SolverVersion()}")
    status = solver.Solve()

    # Print solution.
    if status == pywraplp.Solver.OPTIMAL or status == pywraplp.Solver.FEASIBLE:
        print(f"Total cost = {solver.Objective().Value()}\n")
        for worker in range(num_workers):
            for task in range(num_tasks):
                if x[worker, task].solution_value() > 0.5:
                    print(
                        f"Worker {worker} assigned to task {task}."
                        + f" Cost: {costs[worker][task]}"
                    )
    else:
        print("No solution found.")


if __name__ == "__main__":
    main()
# Out:
# Solving with SCIP 9.0.0 [LP solver: Glop 9.10]
# Total cost = 326.0
#
# Worker 0 assigned to task 6. Cost: 12
# Worker 1 assigned to task 0. Cost: 35
# Worker 1 assigned to task 2. Cost: 55
# Worker 4 assigned to task 4. Cost: 59
# Worker 5 assigned to task 5. Cost: 31
# Worker 5 assigned to task 7. Cost: 34
# Worker 6 assigned to task 1. Cost: 51
# Worker 8 assigned to task 3. Cost: 49

# %% [markdown]
# ## Assignment with Groups

# %%
"""Solve assignment problem for given group of workers."""
from ortools.linear_solver import pywraplp


def main():
    # Data
    costs = [
        [90, 76, 75, 70, 50, 74],
        [35, 85, 55, 65, 48, 101],
        [125, 95, 90, 105, 59, 120],
        [45, 110, 95, 115, 104, 83],
        [60, 105, 80, 75, 59, 62],
        [45, 65, 110, 95, 47, 31],
        [38, 51, 107, 41, 69, 99],
        [47, 85, 57, 71, 92, 77],
        [39, 63, 97, 49, 118, 56],
        [47, 101, 71, 60, 88, 109],
        [17, 39, 103, 64, 61, 92],
        [101, 45, 83, 59, 92, 27],
    ]
    num_workers = len(costs)
    num_tasks = len(costs[0])

    # Allowed groups of workers:
    group1 = [  # Subgroups of workers 0 - 3
        [2, 3],
        [1, 3],
        [1, 2],
        [0, 1],
        [0, 2],
    ]

    group2 = [  # Subgroups of workers 4 - 7
        [6, 7],
        [5, 7],
        [5, 6],
        [4, 5],
        [4, 7],
    ]

    group3 = [  # Subgroups of workers 8 - 11
        [10, 11],
        [9, 11],
        [9, 10],
        [8, 10],
        [8, 11],
    ]

    # Solver.
    # Create the mip solver with the SCIP backend.
    solver = pywraplp.Solver.CreateSolver("SCIP")
    if not solver:
        return

    # Variables
    # x[worker, task] is an array of 0-1 variables, which will be 1
    # if the worker is assigned to the task.
    x = {}
    for worker in range(num_workers):
        for task in range(num_tasks):
            x[worker, task] = solver.BoolVar(f"x[{worker},{task}]")

    # Constraints
    # The total size of the tasks each worker takes on is at most total_size_max.
    for worker in range(num_workers):
        solver.Add(solver.Sum([x[worker, task] for task in range(num_tasks)]) <= 1)

    # Each task is assigned to exactly one worker.
    for task in range(num_tasks):
        solver.Add(solver.Sum([x[worker, task] for worker in range(num_workers)]) == 1)

    # Create variables for each worker, indicating whether they work on some task.
    work = {}
    for worker in range(num_workers):
        work[worker] = solver.BoolVar(f"work[{worker}]")

    for worker in range(num_workers):
        solver.Add(
            work[worker] == solver.Sum([x[worker, task] for task in range(num_tasks)])
        )

    # Group1
    constraint_g1 = solver.Constraint(1, 1)
    for index, _ in enumerate(group1):
        # a*b can be transformed into 0 <= a + b - 2*p <= 1 with p in [0,1]
        # p is True if a AND b, False otherwise
        constraint = solver.Constraint(0, 1)
        constraint.SetCoefficient(work[group1[index][0]], 1)
        constraint.SetCoefficient(work[group1[index][1]], 1)
        p = solver.BoolVar(f"g1_p{index}")
        constraint.SetCoefficient(p, -2)

        constraint_g1.SetCoefficient(p, 1)

    # Group2
    constraint_g2 = solver.Constraint(1, 1)
    for index, _ in enumerate(group2):
        # a*b can be transformed into 0 <= a + b - 2*p <= 1 with p in [0,1]
        # p is True if a AND b, False otherwise
        constraint = solver.Constraint(0, 1)
        constraint.SetCoefficient(work[group2[index][0]], 1)
        constraint.SetCoefficient(work[group2[index][1]], 1)
        p = solver.BoolVar(f"g2_p{index}")
        constraint.SetCoefficient(p, -2)

        constraint_g2.SetCoefficient(p, 1)

    # Group3
    constraint_g3 = solver.Constraint(1, 1)
    for index, _ in enumerate(group3):
        # a*b can be transformed into 0 <= a + b - 2*p <= 1 with p in [0,1]
        # p is True if a AND b, False otherwise
        constraint = solver.Constraint(0, 1)
        constraint.SetCoefficient(work[group3[index][0]], 1)
        constraint.SetCoefficient(work[group3[index][1]], 1)
        p = solver.BoolVar(f"g3_p{index}")
        constraint.SetCoefficient(p, -2)

        constraint_g3.SetCoefficient(p, 1)

    # Objective
    objective_terms = []
    for worker in range(num_workers):
        for task in range(num_tasks):
            objective_terms.append(costs[worker][task] * x[worker, task])
    solver.Minimize(solver.Sum(objective_terms))

    # Solve
    print(f"Solving with {solver.SolverVersion()}")
    status = solver.Solve()

    # Print solution.
    if status == pywraplp.Solver.OPTIMAL or status == pywraplp.Solver.FEASIBLE:
        print(f"Total cost = {solver.Objective().Value()}\n")
        for worker in range(num_workers):
            for task in range(num_tasks):
                if x[worker, task].solution_value() > 0.5:
                    print(
                        f"Worker {worker} assigned to task {task}."
                        + f" Cost: {costs[worker][task]}"
                    )
    else:
        print("No solution found.")


if __name__ == "__main__":
    main()
# Out:
# Solving with SCIP 9.0.0 [LP solver: Glop 9.10]
# Total cost = 239.00000000000003
#
# Worker 0 assigned to task 4. Cost: 50
# Worker 1 assigned to task 2. Cost: 55
# Worker 5 assigned to task 5. Cost: 31
# Worker 6 assigned to task 3. Cost: 41
# Worker 10 assigned to task 0. Cost: 17
# Worker 11 assigned to task 1. Cost: 45
