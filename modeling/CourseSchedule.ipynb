# %% [markdown]
# # Course Assignment Problem (a small exploration)
#
# We have 500 course exams and 3000 students, each course is ensured to have at least one student enrolled, besides, we have 70 time slot. We want to assign each course exam to a time slot, each time slot is given a cost in advance, each student that have courses exammed at the slot will have corresponding cost (This cost indicates students' welfare, because students will feel angry for assignments such as "Not willing to have exams at 8:00 A.M., or Not willing to have exams during weekends, or Not willing to have exams at the end of exams weeks").
#
# We hope to assign each course exam to a time slot such that the total cost is minimized.
#
# CONSTRS:
#
# 1. Students cannot have two exams simultaneously at one slot;
# 2. Each course exam must be assigned to a time slot;
#
# CAUTION:
#
# 1. Different students have different number of courses, range from 3 to 10.

# %%
# data generate ... 

import random
import numpy as np
import gurobipy as grb


def generate_intervals_weights():
    weights = np.array([[1] * 7 for _ in range(10)])
    weights[0] += 3 # 8:00
    weights[5] += 3 # 8:00
    weights[4] += 1 # night exam
    weights[9] += 1 # night exam 
    weights[0:5, -2: ] += 2 # weekend 
    weights[5:10, -2: ] += 4 # weekend
    weights[9, -2: ] += 3 # "goal keeper"
    # The result is just like:
    # [[4 4 4 4 4 6 6]
    #  [1 1 1 1 1 3 3]
    #  [1 1 1 1 1 3 3]
    #  [1 1 1 1 1 3 3]
    #  [2 2 2 2 2 4 4]
    #  [4 4 4 4 4 8 8]
    #  [1 1 1 1 1 5 5]
    #  [1 1 1 1 1 5 5]
    #  [1 1 1 1 1 5 5]
    #  [2 2 2 2 2 8 8]]
    # Two weeks in total, each day has 5 time slots: 8:00~10:00, 10:30~12:30, 14:00~16:00, 16:30~18:30, 19:00~21:00
    # Apparently, students don't like 8:00~10:00, and 19:00~21:00 exams.
    # Apparently too, students don't like exams during weekends.
    weights = weights.flatten()
    return list(weights)

def generate_student_course_relation(num_courses, num_students):
    # 存储学生参加的课程
    student_courses = {}
    course_students = {}
    # 确保每个课程都有学生参加
    for course in range(num_courses):
        if course not in course_students:
            course_students[course] = []
        student = random.randint(0, num_students - 1)
        if student in student_courses:
            student_courses[student].append(course)
        else:
            student_courses[student] = [course]
        course_students[course].append(student)
    
    # 生成每个学生参加的课程数在 2~10 之间
    for student in range(num_students):
        if student not in student_courses:
            student_courses[student] = []
        while len(student_courses[student]) < random.randint(2, 10):
            course = random.randint(0, num_courses - 1)
            if course not in student_courses[student] and len(student_courses[student]) < 10:
                student_courses[student].append(course)
                course_students[course].append(student)
    return student_courses, course_students

def check_feasibility(result, student_courses, course_students, weights, num_courses, num_students, intervals):
    feasible = True
    # check if the result is okay ... 
    # 1. if all courses are assigned ... 
    if len(result.keys()) != num_courses:
        feasible = False
    # 2. if students time conflict ... 
    if not feasible:
        return feasible    
    for student in range(num_students):
        check_interv = set()
        for course in student_courses[student]:
            if result[course] in check_interv:
                print(f"Wrong! Student {student} has conflict with course {course} at interval {result[course]}")
                feasible = False 
            else:
                check_interv.add(result[course])
    return feasible


def solver(student_courses, course_students, weights, num_courses, num_students, intervals):
    model = grb.Model("CourseSchedule")
    x = dict()
    for course in range(num_courses):
        for interv in range(intervals):
            x[course, interv] = model.addVar(
                vtype=grb.GRB.BINARY, name= f"{course}_{interv}"
            )
            # if allocate course i to interval j, 0-1 binary

    # set objective func
    model.modelSense = grb.GRB.MINIMIZE
    model.setObjective(grb.quicksum(
        x[course, interv] * weights[interv] * len(course_students[course]) for course in range(num_courses) for interv in range(intervals)
    ))
    # set constraints ... 
    for course in range(num_courses):
        model.addConstr(grb.quicksum(x[course, interv] for interv in range(intervals)) == 1, f"C_{course}_fill")
    for student in range(num_students):
        for interv in range(intervals):
            model.addConstr(grb.quicksum(x[course, interv] for course in student_courses[student]) <= 1, f"C_{student}_{interv}_leq1")
    
    model.optimize()
    result = dict()
    if model.status == grb.GRB.status.OPTIMAL:
        ofv = model.getObjective().getValue()
        print(f"Objective Value: {ofv}")
        for course in range(num_courses):
            for interv in range(intervals):
                if x[course, interv].x > 0.5:
                    result[course] = interv
                    print(f"Course {course}, with {len(course_students[course])} students, is allocated to interval {interv}")
    return result    

    
if __name__ == "__main__":
    num_courses = 500
    num_students = 3000
    student_courses, course_students = generate_student_course_relation(num_courses, num_students)
    weights = generate_intervals_weights()
    intervals = 70
    result = solver(student_courses, course_students, weights, num_courses, num_students, intervals)
    check = check_feasibility(result, student_courses, course_students, weights, num_courses, num_students, intervals)
    print(f"Pass feasibility check? {check}")
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M3 Pro
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
#
# Optimize a model with 210500 rows, 35000 columns and 962850 nonzeros
# Model fingerprint: 0xd9098d38
# Variable types: 0 continuous, 35000 integer (35000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+01, 4e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 36862.000000
# Presolve removed 7000 rows and 0 columns
# Presolve time: 1.70s
# Presolved: 203500 rows, 35000 columns, 994490 nonzeros
# Variable types: 0 continuous, 35000 integer (35000 binary)
# Found heuristic solution: objective 20565.000000
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.16s
#
# Solved with barrier
#
# Root relaxation: objective 1.325500e+04, 14503 iterations, 2.27 seconds (2.83 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    13255.000000    0.00000   100%     -    4s
#      0     0          -    0      13255.0000 13255.0000  0.00%     -    5s
#
# Explored 1 nodes (17000 simplex iterations) in 5.76 seconds (9.96 work units)
# Thread count was 11 (of 11 available processors)
#
# Solution count 3: 13255 20565 36862
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.325500000000e+04, best bound 1.325500000000e+04, gap 0.0000%
# Objective Value: 13255.0
# Course 0, with 26 students, is allocated to interval 10
# Course 1, with 40 students, is allocated to interval 59
# Course 2, with 23 students, is allocated to interval 7
# Course 3, with 33 students, is allocated to interval 57
# Course 4, with 23 students, is allocated to interval 18
# Course 5, with 29 students, is allocated to interval 22
# Course 6, with 22 students, is allocated to interval 14
# Course 7, with 22 students, is allocated to interval 45
# Course 8, with 21 students, is allocated to interval 15
# Course 9, with 30 students, is allocated to interval 50
# Course 10, with 26 students, is allocated to interval 56
# Course 11, with 33 students, is allocated to interval 14
# Course 12, with 24 students, is allocated to interval 18
# Course 13, with 28 students, is allocated to interval 16
# Course 14, with 28 students, is allocated to interval 22
# Course 15, with 26 students, is allocated to interval 58
# Course 16, with 18 students, is allocated to interval 56
# Course 17, with 26 students, is allocated to interval 24
# Course 18, with 35 students, is allocated to interval 51
# Course 19, with 30 students, is allocated to interval 8
# Course 20, with 28 students, is allocated to interval 45
# Course 21, with 24 students, is allocated to interval 7
# Course 22, with 21 students, is allocated to interval 10
# Course 23, with 27 students, is allocated to interval 7
# Course 24, with 34 students, is allocated to interval 8
# Course 25, with 20 students, is allocated to interval 17
# Course 26, with 25 students, is allocated to interval 44
# Course 27, with 24 students, is allocated to interval 18
# Course 28, with 30 students, is allocated to interval 25
# Course 29, with 21 students, is allocated to interval 46
# Course 30, with 22 students, is allocated to interval 25
# Course 31, with 23 students, is allocated to interval 15
# Course 32, with 29 students, is allocated to interval 51
# Course 33, with 37 students, is allocated to interval 8
# Course 34, with 24 students, is allocated to interval 56
# Course 35, with 29 students, is allocated to interval 57
# Course 36, with 38 students, is allocated to interval 16
# Course 37, with 28 students, is allocated to interval 25
# Course 38, with 23 students, is allocated to interval 44
# Course 39, with 27 students, is allocated to interval 10
# Course 40, with 27 students, is allocated to interval 23
# Course 41, with 23 students, is allocated to interval 56
# Course 42, with 27 students, is allocated to interval 49
# Course 43, with 28 students, is allocated to interval 23
# Course 44, with 24 students, is allocated to interval 24
# Course 45, with 21 students, is allocated to interval 18
# Course 46, with 18 students, is allocated to interval 60
# Course 47, with 30 students, is allocated to interval 49
# Course 48, with 23 students, is allocated to interval 45
# Course 49, with 27 students, is allocated to interval 17
# Course 50, with 30 students, is allocated to interval 49
# Course 51, with 27 students, is allocated to interval 16
# Course 52, with 24 students, is allocated to interval 24
# Course 53, with 17 students, is allocated to interval 11
# Course 54, with 24 students, is allocated to interval 14
# Course 55, with 27 students, is allocated to interval 43
# Course 56, with 28 students, is allocated to interval 43
# Course 57, with 24 students, is allocated to interval 14
# Course 58, with 25 students, is allocated to interval 25
# Course 59, with 40 students, is allocated to interval 25
# Course 60, with 24 students, is allocated to interval 21
# Course 61, with 28 students, is allocated to interval 7
# Course 62, with 30 students, is allocated to interval 49
# Course 63, with 30 students, is allocated to interval 53
# Course 64, with 30 students, is allocated to interval 15
# Course 65, with 24 students, is allocated to interval 21
# Course 66, with 29 students, is allocated to interval 18
# Course 67, with 21 students, is allocated to interval 8
# Course 68, with 33 students, is allocated to interval 50
# Course 69, with 29 students, is allocated to interval 21
# Course 70, with 31 students, is allocated to interval 53
# Course 71, with 28 students, is allocated to interval 42
# Course 72, with 30 students, is allocated to interval 44
# Course 73, with 23 students, is allocated to interval 42
# Course 74, with 25 students, is allocated to interval 15
# Course 75, with 28 students, is allocated to interval 44
# Course 76, with 20 students, is allocated to interval 9
# Course 77, with 33 students, is allocated to interval 11
# Course 78, with 29 students, is allocated to interval 15
# Course 79, with 25 students, is allocated to interval 22
# Course 80, with 25 students, is allocated to interval 17
# Course 81, with 25 students, is allocated to interval 46
# Course 82, with 27 students, is allocated to interval 42
# Course 83, with 24 students, is allocated to interval 58
# Course 84, with 32 students, is allocated to interval 46
# Course 85, with 27 students, is allocated to interval 51
# Course 86, with 21 students, is allocated to interval 10
# Course 87, with 22 students, is allocated to interval 9
# Course 88, with 27 students, is allocated to interval 25
# Course 89, with 30 students, is allocated to interval 53
# Course 90, with 25 students, is allocated to interval 22
# Course 91, with 26 students, is allocated to interval 42
# Course 92, with 26 students, is allocated to interval 46
# Course 93, with 31 students, is allocated to interval 44
# Course 94, with 25 students, is allocated to interval 42
# Course 95, with 26 students, is allocated to interval 52
# Course 96, with 25 students, is allocated to interval 10
# Course 97, with 26 students, is allocated to interval 56
# Course 98, with 32 students, is allocated to interval 42
# Course 99, with 28 students, is allocated to interval 9
# Course 100, with 27 students, is allocated to interval 24
# Course 101, with 25 students, is allocated to interval 53
# Course 102, with 33 students, is allocated to interval 9
# Course 103, with 35 students, is allocated to interval 45
# Course 104, with 33 students, is allocated to interval 7
# Course 105, with 27 students, is allocated to interval 43
# Course 106, with 28 students, is allocated to interval 52
# Course 107, with 22 students, is allocated to interval 8
# Course 108, with 22 students, is allocated to interval 7
# Course 109, with 19 students, is allocated to interval 8
# Course 110, with 28 students, is allocated to interval 23
# Course 111, with 26 students, is allocated to interval 59
# Course 112, with 22 students, is allocated to interval 46
# Course 113, with 29 students, is allocated to interval 44
# Course 114, with 35 students, is allocated to interval 44
# Course 115, with 24 students, is allocated to interval 14
# Course 116, with 27 students, is allocated to interval 58
# Course 117, with 30 students, is allocated to interval 59
# Course 118, with 26 students, is allocated to interval 56
# Course 119, with 25 students, is allocated to interval 56
# Course 120, with 34 students, is allocated to interval 21
# Course 121, with 27 students, is allocated to interval 17
# Course 122, with 30 students, is allocated to interval 7
# Course 123, with 40 students, is allocated to interval 14
# Course 124, with 26 students, is allocated to interval 16
# Course 125, with 19 students, is allocated to interval 11
# Course 126, with 14 students, is allocated to interval 60
# Course 127, with 29 students, is allocated to interval 52
# Course 128, with 20 students, is allocated to interval 7
# Course 129, with 26 students, is allocated to interval 23
# Course 130, with 32 students, is allocated to interval 11
# Course 131, with 23 students, is allocated to interval 46
# Course 132, with 30 students, is allocated to interval 24
# Course 133, with 26 students, is allocated to interval 42
# Course 134, with 22 students, is allocated to interval 57
# Course 135, with 21 students, is allocated to interval 9
# Course 136, with 21 students, is allocated to interval 15
# Course 137, with 20 students, is allocated to interval 50
# Course 138, with 30 students, is allocated to interval 11
# Course 139, with 23 students, is allocated to interval 7
# Course 140, with 28 students, is allocated to interval 44
# Course 141, with 19 students, is allocated to interval 52
# Course 142, with 32 students, is allocated to interval 10
# Course 143, with 20 students, is allocated to interval 59
# Course 144, with 37 students, is allocated to interval 21
# Course 145, with 24 students, is allocated to interval 25
# Course 146, with 31 students, is allocated to interval 52
# Course 147, with 25 students, is allocated to interval 23
# Course 148, with 27 students, is allocated to interval 10
# Course 149, with 31 students, is allocated to interval 51
# Course 150, with 16 students, is allocated to interval 60
# Course 151, with 21 students, is allocated to interval 56
# Course 152, with 23 students, is allocated to interval 18
# Course 153, with 22 students, is allocated to interval 10
# Course 154, with 21 students, is allocated to interval 46
# Course 155, with 24 students, is allocated to interval 25
# Course 156, with 27 students, is allocated to interval 49
# Course 157, with 27 students, is allocated to interval 42
# Course 158, with 27 students, is allocated to interval 9
# Course 159, with 24 students, is allocated to interval 9
# Course 160, with 23 students, is allocated to interval 14
# Course 161, with 28 students, is allocated to interval 16
# Course 162, with 22 students, is allocated to interval 46
# Course 163, with 30 students, is allocated to interval 43
# Course 164, with 31 students, is allocated to interval 16
# Course 165, with 19 students, is allocated to interval 60
# Course 166, with 31 students, is allocated to interval 23
# Course 167, with 25 students, is allocated to interval 18
# Course 168, with 31 students, is allocated to interval 45
# Course 169, with 19 students, is allocated to interval 53
# Course 170, with 31 students, is allocated to interval 15
# Course 171, with 35 students, is allocated to interval 57
# Course 172, with 31 students, is allocated to interval 22
# Course 173, with 20 students, is allocated to interval 11
# Course 174, with 32 students, is allocated to interval 58
# Course 175, with 23 students, is allocated to interval 60
# Course 176, with 24 students, is allocated to interval 57
# Course 177, with 30 students, is allocated to interval 23
# Course 178, with 21 students, is allocated to interval 53
# Course 179, with 31 students, is allocated to interval 50
# Course 180, with 24 students, is allocated to interval 17
# Course 181, with 37 students, is allocated to interval 43
# Course 182, with 27 students, is allocated to interval 60
# Course 183, with 20 students, is allocated to interval 58
# Course 184, with 21 students, is allocated to interval 10
# Course 185, with 33 students, is allocated to interval 49
# Course 186, with 28 students, is allocated to interval 25
# Course 187, with 33 students, is allocated to interval 59
# Course 188, with 27 students, is allocated to interval 57
# Course 189, with 26 students, is allocated to interval 58
# Course 190, with 27 students, is allocated to interval 10
# Course 191, with 25 students, is allocated to interval 57
# Course 192, with 35 students, is allocated to interval 43
# Course 193, with 18 students, is allocated to interval 16
# Course 194, with 26 students, is allocated to interval 21
# Course 195, with 33 students, is allocated to interval 42
# Course 196, with 27 students, is allocated to interval 25
# Course 197, with 19 students, is allocated to interval 14
# Course 198, with 29 students, is allocated to interval 24
# Course 199, with 23 students, is allocated to interval 52
# Course 200, with 30 students, is allocated to interval 8
# Course 201, with 23 students, is allocated to interval 57
# Course 202, with 35 students, is allocated to interval 44
# Course 203, with 21 students, is allocated to interval 58
# Course 204, with 20 students, is allocated to interval 58
# Course 205, with 28 students, is allocated to interval 57
# Course 206, with 28 students, is allocated to interval 45
# Course 207, with 27 students, is allocated to interval 17
# Course 208, with 19 students, is allocated to interval 60
# Course 209, with 23 students, is allocated to interval 60
# Course 210, with 25 students, is allocated to interval 58
# Course 211, with 23 students, is allocated to interval 52
# Course 212, with 27 students, is allocated to interval 16
# Course 213, with 23 students, is allocated to interval 9
# Course 214, with 29 students, is allocated to interval 56
# Course 215, with 28 students, is allocated to interval 56
# Course 216, with 21 students, is allocated to interval 59
# Course 217, with 25 students, is allocated to interval 24
# Course 218, with 38 students, is allocated to interval 42
# Course 219, with 25 students, is allocated to interval 15
# Course 220, with 25 students, is allocated to interval 58
# Course 221, with 24 students, is allocated to interval 14
# Course 222, with 21 students, is allocated to interval 57
# Course 223, with 22 students, is allocated to interval 45
# Course 224, with 27 students, is allocated to interval 50
# Course 225, with 24 students, is allocated to interval 53
# Course 226, with 18 students, is allocated to interval 52
# Course 227, with 22 students, is allocated to interval 11
# Course 228, with 23 students, is allocated to interval 52
# Course 229, with 27 students, is allocated to interval 11
# Course 230, with 25 students, is allocated to interval 11
# Course 231, with 35 students, is allocated to interval 49
# Course 232, with 32 students, is allocated to interval 44
# Course 233, with 30 students, is allocated to interval 14
# Course 234, with 25 students, is allocated to interval 25
# Course 235, with 24 students, is allocated to interval 21
# Course 236, with 31 students, is allocated to interval 45
# Course 237, with 24 students, is allocated to interval 10
# Course 238, with 27 students, is allocated to interval 46
# Course 239, with 16 students, is allocated to interval 60
# Course 240, with 30 students, is allocated to interval 43
# Course 241, with 27 students, is allocated to interval 25
# Course 242, with 31 students, is allocated to interval 60
# Course 243, with 30 students, is allocated to interval 11
# Course 244, with 34 students, is allocated to interval 18
# Course 245, with 34 students, is allocated to interval 23
# Course 246, with 31 students, is allocated to interval 10
# Course 247, with 26 students, is allocated to interval 14
# Course 248, with 22 students, is allocated to interval 25
# Course 249, with 30 students, is allocated to interval 59
# Course 250, with 28 students, is allocated to interval 10
# Course 251, with 29 students, is allocated to interval 51
# Course 252, with 21 students, is allocated to interval 21
# Course 253, with 22 students, is allocated to interval 52
# Course 254, with 19 students, is allocated to interval 60
# Course 255, with 21 students, is allocated to interval 51
# Course 256, with 23 students, is allocated to interval 49
# Course 257, with 27 students, is allocated to interval 43
# Course 258, with 23 students, is allocated to interval 58
# Course 259, with 25 students, is allocated to interval 21
# Course 260, with 30 students, is allocated to interval 15
# Course 261, with 30 students, is allocated to interval 18
# Course 262, with 28 students, is allocated to interval 18
# Course 263, with 36 students, is allocated to interval 59
# Course 264, with 17 students, is allocated to interval 60
# Course 265, with 22 students, is allocated to interval 17
# Course 266, with 27 students, is allocated to interval 52
# Course 267, with 29 students, is allocated to interval 46
# Course 268, with 29 students, is allocated to interval 17
# Course 269, with 22 students, is allocated to interval 10
# Course 270, with 29 students, is allocated to interval 9
# Course 271, with 26 students, is allocated to interval 56
# Course 272, with 27 students, is allocated to interval 57
# Course 273, with 27 students, is allocated to interval 46
# Course 274, with 21 students, is allocated to interval 46
# Course 275, with 19 students, is allocated to interval 60
# Course 276, with 29 students, is allocated to interval 18
# Course 277, with 26 students, is allocated to interval 60
# Course 278, with 19 students, is allocated to interval 22
# Course 279, with 20 students, is allocated to interval 60
# Course 280, with 26 students, is allocated to interval 22
# Course 281, with 20 students, is allocated to interval 9
# Course 282, with 31 students, is allocated to interval 51
# Course 283, with 28 students, is allocated to interval 45
# Course 284, with 25 students, is allocated to interval 51
# Course 285, with 17 students, is allocated to interval 60
# Course 286, with 26 students, is allocated to interval 7
# Course 287, with 30 students, is allocated to interval 22
# Course 288, with 22 students, is allocated to interval 51
# Course 289, with 26 students, is allocated to interval 59
# Course 290, with 26 students, is allocated to interval 16
# Course 291, with 25 students, is allocated to interval 14
# Course 292, with 27 students, is allocated to interval 22
# Course 293, with 18 students, is allocated to interval 60
# Course 294, with 28 students, is allocated to interval 10
# Course 295, with 21 students, is allocated to interval 59
# Course 296, with 26 students, is allocated to interval 7
# Course 297, with 22 students, is allocated to interval 16
# Course 298, with 28 students, is allocated to interval 53
# Course 299, with 27 students, is allocated to interval 50
# Course 300, with 29 students, is allocated to interval 53
# Course 301, with 23 students, is allocated to interval 42
# Course 302, with 36 students, is allocated to interval 43
# Course 303, with 31 students, is allocated to interval 9
# Course 304, with 27 students, is allocated to interval 24
# Course 305, with 19 students, is allocated to interval 11
# Course 306, with 22 students, is allocated to interval 8
# Course 307, with 31 students, is allocated to interval 58
# Course 308, with 23 students, is allocated to interval 18
# Course 309, with 23 students, is allocated to interval 10
# Course 310, with 29 students, is allocated to interval 15
# Course 311, with 24 students, is allocated to interval 17
# Course 312, with 32 students, is allocated to interval 24
# Course 313, with 30 students, is allocated to interval 23
# Course 314, with 24 students, is allocated to interval 25
# Course 315, with 23 students, is allocated to interval 43
# Course 316, with 26 students, is allocated to interval 44
# Course 317, with 19 students, is allocated to interval 43
# Course 318, with 26 students, is allocated to interval 58
# Course 319, with 27 students, is allocated to interval 17
# Course 320, with 21 students, is allocated to interval 46
# Course 321, with 34 students, is allocated to interval 50
# Course 322, with 25 students, is allocated to interval 16
# Course 323, with 25 students, is allocated to interval 45
# Course 324, with 31 students, is allocated to interval 25
# Course 325, with 29 students, is allocated to interval 14
# Course 326, with 30 students, is allocated to interval 11
# Course 327, with 27 students, is allocated to interval 50
# Course 328, with 26 students, is allocated to interval 11
# Course 329, with 28 students, is allocated to interval 16
# Course 330, with 36 students, is allocated to interval 46
# Course 331, with 31 students, is allocated to interval 22
# Course 332, with 26 students, is allocated to interval 22
# Course 333, with 18 students, is allocated to interval 60
# Course 334, with 25 students, is allocated to interval 9
# Course 335, with 23 students, is allocated to interval 24
# Course 336, with 23 students, is allocated to interval 57
# Course 337, with 28 students, is allocated to interval 59
# Course 338, with 22 students, is allocated to interval 8
# Course 339, with 29 students, is allocated to interval 44
# Course 340, with 28 students, is allocated to interval 18
# Course 341, with 29 students, is allocated to interval 21
# Course 342, with 31 students, is allocated to interval 24
# Course 343, with 23 students, is allocated to interval 46
# Course 344, with 31 students, is allocated to interval 11
# Course 345, with 35 students, is allocated to interval 58
# Course 346, with 35 students, is allocated to interval 42
# Course 347, with 20 students, is allocated to interval 44
# Course 348, with 33 students, is allocated to interval 16
# Course 349, with 20 students, is allocated to interval 23
# Course 350, with 26 students, is allocated to interval 16
# Course 351, with 21 students, is allocated to interval 60
# Course 352, with 28 students, is allocated to interval 24
# Course 353, with 26 students, is allocated to interval 22
# Course 354, with 31 students, is allocated to interval 58
# Course 355, with 28 students, is allocated to interval 8
# Course 356, with 31 students, is allocated to interval 17
# Course 357, with 21 students, is allocated to interval 43
# Course 358, with 18 students, is allocated to interval 52
# Course 359, with 22 students, is allocated to interval 57
# Course 360, with 27 students, is allocated to interval 17
# Course 361, with 26 students, is allocated to interval 7
# Course 362, with 29 students, is allocated to interval 17
# Course 363, with 28 students, is allocated to interval 18
# Course 364, with 24 students, is allocated to interval 51
# Course 365, with 27 students, is allocated to interval 49
# Course 366, with 31 students, is allocated to interval 24
# Course 367, with 19 students, is allocated to interval 59
# Course 368, with 19 students, is allocated to interval 60
# Course 369, with 23 students, is allocated to interval 7
# Course 370, with 25 students, is allocated to interval 46
# Course 371, with 24 students, is allocated to interval 53
# Course 372, with 16 students, is allocated to interval 8
# Course 373, with 35 students, is allocated to interval 8
# Course 374, with 26 students, is allocated to interval 51
# Course 375, with 26 students, is allocated to interval 22
# Course 376, with 26 students, is allocated to interval 23
# Course 377, with 32 students, is allocated to interval 45
# Course 378, with 34 students, is allocated to interval 14
# Course 379, with 26 students, is allocated to interval 51
# Course 380, with 32 students, is allocated to interval 23
# Course 381, with 22 students, is allocated to interval 8
# Course 382, with 31 students, is allocated to interval 9
# Course 383, with 35 students, is allocated to interval 23
# Course 384, with 18 students, is allocated to interval 24
# Course 385, with 31 students, is allocated to interval 52
# Course 386, with 27 students, is allocated to interval 60
# Course 387, with 24 students, is allocated to interval 8
# Course 388, with 34 students, is allocated to interval 44
# Course 389, with 33 students, is allocated to interval 52
# Course 390, with 22 students, is allocated to interval 46
# Course 391, with 32 students, is allocated to interval 21
# Course 392, with 22 students, is allocated to interval 52
# Course 393, with 28 students, is allocated to interval 45
# Course 394, with 16 students, is allocated to interval 60
# Course 395, with 27 students, is allocated to interval 59
# Course 396, with 29 students, is allocated to interval 15
# Course 397, with 24 students, is allocated to interval 58
# Course 398, with 22 students, is allocated to interval 58
# Course 399, with 29 students, is allocated to interval 21
# Course 400, with 26 students, is allocated to interval 50
# Course 401, with 22 students, is allocated to interval 24
# Course 402, with 34 students, is allocated to interval 7
# Course 403, with 24 students, is allocated to interval 60
# Course 404, with 27 students, is allocated to interval 14
# Course 405, with 29 students, is allocated to interval 50
# Course 406, with 26 students, is allocated to interval 15
# Course 407, with 21 students, is allocated to interval 52
# Course 408, with 34 students, is allocated to interval 9
# Course 409, with 24 students, is allocated to interval 53
# Course 410, with 25 students, is allocated to interval 22
# Course 411, with 25 students, is allocated to interval 15
# Course 412, with 24 students, is allocated to interval 8
# Course 413, with 29 students, is allocated to interval 11
# Course 414, with 28 students, is allocated to interval 44
# Course 415, with 31 students, is allocated to interval 53
# Course 416, with 26 students, is allocated to interval 42
# Course 417, with 29 students, is allocated to interval 50
# Course 418, with 23 students, is allocated to interval 43
# Course 419, with 21 students, is allocated to interval 53
# Course 420, with 30 students, is allocated to interval 42
# Course 421, with 24 students, is allocated to interval 8
# Course 422, with 23 students, is allocated to interval 58
# Course 423, with 37 students, is allocated to interval 22
# Course 424, with 35 students, is allocated to interval 49
# Course 425, with 25 students, is allocated to interval 45
# Course 426, with 24 students, is allocated to interval 7
# Course 427, with 24 students, is allocated to interval 51
# Course 428, with 34 students, is allocated to interval 56
# Course 429, with 33 students, is allocated to interval 16
# Course 430, with 26 students, is allocated to interval 57
# Course 431, with 26 students, is allocated to interval 9
# Course 432, with 26 students, is allocated to interval 44
# Course 433, with 27 students, is allocated to interval 7
# Course 434, with 19 students, is allocated to interval 60
# Course 435, with 33 students, is allocated to interval 49
# Course 436, with 34 students, is allocated to interval 56
# Course 437, with 28 students, is allocated to interval 8
# Course 438, with 30 students, is allocated to interval 18
# Course 439, with 23 students, is allocated to interval 25
# Course 440, with 28 students, is allocated to interval 52
# Course 441, with 32 students, is allocated to interval 46
# Course 442, with 23 students, is allocated to interval 50
# Course 443, with 28 students, is allocated to interval 24
# Course 444, with 23 students, is allocated to interval 24
# Course 445, with 24 students, is allocated to interval 58
# Course 446, with 26 students, is allocated to interval 57
# Course 447, with 19 students, is allocated to interval 50
# Course 448, with 26 students, is allocated to interval 7
# Course 449, with 32 students, is allocated to interval 10
# Course 450, with 25 students, is allocated to interval 15
# Course 451, with 22 students, is allocated to interval 7
# Course 452, with 37 students, is allocated to interval 21
# Course 453, with 31 students, is allocated to interval 15
# Course 454, with 23 students, is allocated to interval 43
# Course 455, with 22 students, is allocated to interval 21
# Course 456, with 23 students, is allocated to interval 16
# Course 457, with 30 students, is allocated to interval 22
# Course 458, with 34 students, is allocated to interval 17
# Course 459, with 25 students, is allocated to interval 42
# Course 460, with 33 students, is allocated to interval 10
# Course 461, with 34 students, is allocated to interval 45
# Course 462, with 26 students, is allocated to interval 8
# Course 463, with 33 students, is allocated to interval 52
# Course 464, with 27 students, is allocated to interval 51
# Course 465, with 25 students, is allocated to interval 18
# Course 466, with 27 students, is allocated to interval 49
# Course 467, with 21 students, is allocated to interval 14
# Course 468, with 18 students, is allocated to interval 52
# Course 469, with 24 students, is allocated to interval 22
# Course 470, with 31 students, is allocated to interval 23
# Course 471, with 26 students, is allocated to interval 9
# Course 472, with 24 students, is allocated to interval 10
# Course 473, with 34 students, is allocated to interval 11
# Course 474, with 26 students, is allocated to interval 42
# Course 475, with 33 students, is allocated to interval 50
# Course 476, with 23 students, is allocated to interval 58
# Course 477, with 26 students, is allocated to interval 51
# Course 478, with 26 students, is allocated to interval 17
# Course 479, with 25 students, is allocated to interval 45
# Course 480, with 27 students, is allocated to interval 53
# Course 481, with 29 students, is allocated to interval 42
# Course 482, with 35 students, is allocated to interval 11
# Course 483, with 24 students, is allocated to interval 43
# Course 484, with 28 students, is allocated to interval 42
# Course 485, with 19 students, is allocated to interval 10
# Course 486, with 28 students, is allocated to interval 59
# Course 487, with 17 students, is allocated to interval 60
# Course 488, with 33 students, is allocated to interval 58
# Course 489, with 30 students, is allocated to interval 11
# Course 490, with 39 students, is allocated to interval 14
# Course 491, with 22 students, is allocated to interval 58
# Course 492, with 28 students, is allocated to interval 46
# Course 493, with 28 students, is allocated to interval 56
# Course 494, with 34 students, is allocated to interval 15
# Course 495, with 25 students, is allocated to interval 59
# Course 496, with 32 students, is allocated to interval 17
# Course 497, with 26 students, is allocated to interval 45
# Course 498, with 29 students, is allocated to interval 16
# Course 499, with 26 students, is allocated to interval 57
# Pass feasibility check? True

# %%
# checked for feasibility.
