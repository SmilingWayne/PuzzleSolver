# %% [markdown]
# # Public Transit Play I
#
# We define the "Maximum Stations Number" as
#
# **the minimum number of stations one needs to pass through to reach all other stations in a subway network.**
#
# This code is designed to identify the station with the minimum "Maximum Stations Number" within the Nanjing subway network.
#
# We use The real-world data from Nanjing Railway in Jiangsu Province, China, and Shanghai, China.

# %%
import networkx as nx

def build_graph_from_metro_data(metro_network):
    # 创建无向图
    graph = nx.Graph()
    for station, connections in metro_network.items():
        for neighbor, distance in connections.items():
            # graph.add_edge(station, neighbor, weight=distance)
            graph.add_edge(station, neighbor, weight=1)
    return graph

def read_metro_data(file_path):
    from collections import defaultdict

    # 邻接表表示的地铁网络图
    metro_network = defaultdict(dict)

    with open(file_path, 'r', encoding='utf-8') as file:
        current_line = None
        for line in file:
            line = line.strip()
            if line.startswith("Line"):
                # 读取线路名
                current_line = line
            elif line:
                # 读取站点和距离信息
                station1, station2, distance = line.split(",")
                distance = int(distance)  # 转换距离为整数
                # 添加到邻接表，视为无向图
                metro_network[station1][station2] = distance
                metro_network[station2][station1] = distance
                # metro_network[station1][station2] = 1
                # metro_network[station2][station1] = 1

    return metro_network

# 示例调用
file_path = "./data/PublicTransit/NJ.txt"  # 替换为你的实际文件路径
# file_path = "./data/PublicTransit/SH_new.txt"  # 替换为你的实际文件路径
# file_path = "./data/PublicTransit/BJ.txt"  # 替换为你的实际文件路径
metro_network = read_metro_data(file_path)

# 打印部分结果查看结构
for station, connections in list(metro_network.items())[:5]:
    print(f"Station: {station}, Connections: {connections}")
    

def calculate_shortest_paths_for_all_stations(graph):
    # 保存每个站点到其他所有站点的最短距离和路径
    shortest_paths_info = {}

    # 使用 NetworkX 的 all_pairs_dijkstra 函数
    all_pairs_shortest_paths = dict(nx.all_pairs_dijkstra(graph, weight="weight"))

    for start_station, (distances, paths) in all_pairs_shortest_paths.items():
        shortest_paths_info[start_station] = {
            "distances": distances,  # 起点到其他站点的最短距离
            "paths": paths           # 起点到其他站点的最短路径
        }

    return shortest_paths_info

# 示例调用
graph = build_graph_from_metro_data(metro_network)  # 使用之前的 build_graph_from_metro_data 函数
shortest_paths_info = calculate_shortest_paths_for_all_stations(graph)

max_distance_info = {}  # 保存每个站点的最远距离、路径和最多边数信息

for station, info in shortest_paths_info.items():
    distances = info["distances"]
    paths = info["paths"]

    # 计算最远距离和最多边数
    farthest_station = max(distances, key=distances.get)  # 最远距离对应的终点站
    max_distance = distances[farthest_station]           # 最远距离
    max_edges = len(paths[farthest_station]) - 1         # 最多边数（路径长度 - 1）
    max_path = paths[farthest_station]                  # 最远距离对应的路径

    # 保存结果
    max_distance_info[station] = {
        "farthest_station": farthest_station,
        "max_distance": max_distance,
        "max_edges": max_edges,
        "max_path": max_path
    }

# 筛选“到其他所有节点的最远距离最短”的前5个节点
sorted_stations = sorted(
    max_distance_info.items(),
    key=lambda x: x[1]["max_distance"]
)[:5]  # 根据最远距离升序取前5个节点

# 打印筛选结果
print("到其他所有节点的最远距离最短的前5个节点:")
for station, result in sorted_stations:
    print(f"站点 {station}:")
    print(f"  到达最远站点: {result['farthest_station']}")
    print(f"  最远距离: {result['max_distance']} 米")
    print(f"  路径经过最多边数: {result['max_edges']}")
    print(f"  对应路径: {result['max_path']}")
    print()
# Out:
# Station: 八卦洲大桥南, Connections: {'笆斗山': 1370}
# Station: 笆斗山, Connections: {'八卦洲大桥南': 1370, '燕子矶': 1292}
# Station: 燕子矶, Connections: {'笆斗山': 1292, '吉祥庵': 1115}
# Station: 吉祥庵, Connections: {'燕子矶': 1115, '晓庄': 1007}
# Station: 晓庄, Connections: {'吉祥庵': 1007, '迈皋桥': 1910, '万寿': 1405, '幕府山': 1996}
# 到其他所有节点的最远距离最短的前5个节点:
# 站点 珠江路:
#   到达最远站点: 金牛湖
#   最远距离: 25 米
#   路径经过最多边数: 25
#   对应路径: ['珠江路', '鼓楼', '玄武门', '新模范马路', '南京站', '小市', '五塘广场', '上元门', '柳洲东路', '天润城', '泰冯路', '高新开发区', '信息工程大学', '卸甲甸', '大厂', '葛塘', '长芦', '化工园', '六和开发区', '龙池', '雄州', '凤凰山公园', '方州广场', '沈桥', '八百桥', '金牛湖']
#
# 站点 大行宫:
#   到达最远站点: 金牛湖
#   最远距离: 25 米
#   路径经过最多边数: 25
#   对应路径: ['大行宫', '浮桥', '鸡鸣寺', '南京林业大学新庄', '南京站', '小市', '五塘广场', '上元门', '柳洲东路', '天润城', '泰冯路', '高新开发区', '信息工程大学', '卸甲甸', '大厂', '葛塘', '长芦', '化工园', '六和开发区', '龙池', '雄州', '凤凰山公园', '方州广场', '沈桥', '八百桥', '金牛湖']
#
# 站点 浮桥:
#   到达最远站点: 无想山
#   最远距离: 25 米
#   路径经过最多边数: 25
#   对应路径: ['浮桥', '大行宫', '常府街', '夫子庙', '武定门', '雨花门', '卡子门', '大明路', '明发广场', '南京南站', '翠屏山', '河海大学·佛城西路', '吉印大道', '正方中路', '翔宇路北', '翔宇路南', '禄口机场', '空港新城江宁', '柘塘', '空港新城溧水', '群力', '卧龙湖', '溧水', '中山湖', '幸庄', '无想山']
#
# 站点 鼓楼:
#   到达最远站点: 无想山
#   最远距离: 26 米
#   路径经过最多边数: 26
#   对应路径: ['鼓楼', '珠江路', '新街口', '张府园', '三山街', '中华门', '安德门', '天隆寺', '软件大道', '花神庙', '南京南站', '翠屏山', '河海大学·佛城西路', '吉印大道', '正方中路', '翔宇路北', '翔宇路南', '禄口机场', '空港新城江宁', '柘塘', '空港新城溧水', '群力', '卧龙湖', '溧水', '中山湖', '幸庄', '无想山']
#
# 站点 鸡鸣寺:
#   到达最远站点: 无想山
#   最远距离: 26 米
#   路径经过最多边数: 26
#   对应路径: ['鸡鸣寺', '浮桥', '大行宫', '常府街', '夫子庙', '武定门', '雨花门', '卡子门', '大明路', '明发广场', '南京南站', '翠屏山', '河海大学·佛城西路', '吉印大道', '正方中路', '翔宇路北', '翔宇路南', '禄口机场', '空港新城江宁', '柘塘', '空港新城溧水', '群力', '卧龙湖', '溧水', '中山湖', '幸庄', '无想山']

# %%
metro_network
# Out:
# defaultdict(dict,
#             {'八卦洲大桥南': {'笆斗山': 1},
#              '笆斗山': {'八卦洲大桥南': 1, '燕子矶': 1},
#              '燕子矶': {'笆斗山': 1, '吉祥庵': 1},
#              '吉祥庵': {'燕子矶': 1, '晓庄': 1},
#              '晓庄': {'吉祥庵': 1, '迈皋桥': 1, '万寿': 1, '幕府山': 1},
#              '迈皋桥': {'晓庄': 1, '红山动物园': 1},
#              '红山动物园': {'迈皋桥': 1, '南京站': 1},
#              '南京站': {'红山动物园': 1, '新模范马路': 1, '小市': 1, '南京林业大学新庄': 1},
#              '新模范马路': {'南京站': 1, '玄武门': 1},
#              '玄武门': {'新模范马路': 1, '鼓楼': 1},
#              '鼓楼': {'玄武门': 1, '珠江路': 1},
#              '珠江路': {'鼓楼': 1, '新街口': 1},
#              '新街口': {'珠江路': 1, '张府园': 1, '上海路': 1, '大行宫': 1},
#              '张府园': {'新街口': 1, '三山街': 1},
#              '三山街': {'张府园': 1, '中华门': 1},
#              '中华门': {'三山街': 1, '安德门': 1},
#              '安德门': {'中华门': 1, '天隆寺': 1, '小行': 1},
#              '天隆寺': {'安德门': 1, '软件大道': 1},
#              '软件大道': {'天隆寺': 1, '花神庙': 1},
#              '花神庙': {'软件大道': 1, '南京南站': 1},
#              '南京南站': {'花神庙': 1,
#               '双龙大道': 1,
#               '明发广场': 1,
#               '宏运大道': 1,
#               '翠屏山': 1,
#               '景明佳园站': 1},
#              '双龙大道': {'南京南站': 1, '河定桥': 1},
#              '河定桥': {'双龙大道': 1, '胜太路': 1},
#              '胜太路': {'河定桥': 1, '百家湖': 1},
#              '百家湖': {'胜太路': 1, '小龙湾': 1},
#              '小龙湾': {'百家湖': 1, '竹山路': 1},
#              '竹山路': {'小龙湾': 1, '天印大道': 1},
#              '天印大道': {'竹山路': 1, '龙眠大道': 1},
#              '龙眠大道': {'天印大道': 1, '南医大江苏经贸学院': 1},
#              '南医大江苏经贸学院': {'龙眠大道': 1, '南京交院': 1},
#              '南京交院': {'南医大江苏经贸学院': 1, '中国药科大学': 1},
#              '中国药科大学': {'南京交院': 1},
#              '鱼嘴': {'天保街': 1},
#              '天保街': {'鱼嘴': 1, '青莲街': 1},
#              '青莲街': {'天保街': 1, '螺塘街': 1},
#              '螺塘街': {'青莲街': 1},
#              '螺塘路': {'油坊桥': 1, '太清路': 1, '西善桥': 1},
#              '油坊桥': {'螺塘路': 1, '雨润大街': 1},
#              '雨润大街': {'油坊桥': 1, '元通': 1},
#              '元通': {'雨润大街': 1, '奥体东站': 1, '中胜': 1, '奥体中心': 1},
#              '奥体东站': {'元通': 1, '兴隆大街': 1},
#              '兴隆大街': {'奥体东站': 1, '集庆门大街': 1},
#              '集庆门大街': {'兴隆大街': 1, '云锦路': 1},
#              '云锦路': {'集庆门大街': 1, '莫愁湖': 1},
#              '莫愁湖': {'云锦路': 1, '汉中门': 1},
#              '汉中门': {'莫愁湖': 1, '上海路': 1},
#              '上海路': {'汉中门': 1, '新街口': 1},
#              '大行宫': {'新街口': 1, '西安门': 1, '浮桥': 1, '常府街': 1},
#              '西安门': {'大行宫': 1, '明故宫': 1},
#              '明故宫': {'西安门': 1, '苜蓿园': 1},
#              '苜蓿园': {'明故宫': 1, '下马坊': 1},
#              '下马坊': {'苜蓿园': 1, '孝陵卫': 1},
#              '孝陵卫': {'下马坊': 1, '钟灵街': 1},
#              '钟灵街': {'孝陵卫': 1, '马群': 1},
#              '马群': {'钟灵街': 1, '金马路': 1, '白水桥': 1},
#              '金马路': {'马群': 1, '仙鹤门': 1},
#              '仙鹤门': {'金马路': 1, '学则路': 1},
#              '学则路': {'仙鹤门': 1, '仙林中心': 1},
#              '仙林中心': {'学则路': 1, '羊山公园': 1},
#              '羊山公园': {'仙林中心': 1, '南大仙林校区': 1},
#              '南大仙林校区': {'羊山公园': 1, '经天路': 1},
#              '经天路': {'南大仙林校区': 1},
#              '林场': {'星火路': 1},
#              '星火路': {'林场': 1, '东大成贤学院站': 1},
#              '东大成贤学院站': {'星火路': 1, '泰冯路': 1},
#              '泰冯路': {'东大成贤学院站': 1, '天润城': 1, '泰山新村': 1, '高新开发区': 1},
#              '天润城': {'泰冯路': 1, '柳洲东路': 1},
#              '柳洲东路': {'天润城': 1, '上元门': 1},
#              '上元门': {'柳洲东路': 1, '五塘广场': 1},
#              '五塘广场': {'上元门': 1, '小市': 1, '幕府山': 1, '幕府西路': 1},
#              '小市': {'五塘广场': 1, '南京站': 1},
#              '南京林业大学新庄': {'南京站': 1, '鸡鸣寺': 1},
#              '鸡鸣寺': {'南京林业大学新庄': 1, '浮桥': 1},
#              '浮桥': {'鸡鸣寺': 1, '大行宫': 1},
#              '常府街': {'大行宫': 1, '夫子庙': 1},
#              '夫子庙': {'常府街': 1, '武定门': 1},
#              '武定门': {'夫子庙': 1, '雨花门': 1},
#              '雨花门': {'武定门': 1, '卡子门': 1},
#              '卡子门': {'雨花门': 1, '大明路': 1},
#              '大明路': {'卡子门': 1, '明发广场': 1},
#              '明发广场': {'大明路': 1, '南京南站': 1},
#              '宏运大道': {'南京南站': 1, '胜太西路': 1},
#              '胜太西路': {'宏运大道': 1, '天元西路': 1},
#              '天元西路': {'胜太西路': 1, '九龙湖': 1},
#              '九龙湖': {'天元西路': 1, '诚信大道': 1},
#              '诚信大道': {'九龙湖': 1, '东大九龙湖校区': 1},
#              '东大九龙湖校区': {'诚信大道': 1, '秣周东路': 1},
#              '秣周东路': {'东大九龙湖校区': 1},
#              '龙江站': {'草场门站': 1},
#              '草场门站': {'龙江站': 1, '云南路站': 1},
#              '云南路站': {'草场门站': 1, '鼓楼站': 1},
#              '鼓楼站': {'云南路站': 1, '鸡鸣寺站': 1},
#              '鸡鸣寺站': {'鼓楼站': 1, '九华山站': 1},
#              '九华山站': {'鸡鸣寺站': 1, '岗子村站': 1},
#              '岗子村站': {'九华山站': 1, '蒋王庙站': 1},
#              '蒋王庙站': {'岗子村站': 1, '王家湾站': 1},
#              '王家湾站': {'蒋王庙站': 1, '聚宝山站': 1},
#              '聚宝山站': {'王家湾站': 1, '徐庄站': 1},
#              '徐庄站': {'聚宝山站': 1, '金马路站': 1},
#              '金马路站': {'徐庄站': 1, '汇通路站': 1},
#              '汇通路站': {'金马路站': 1, '灵山站': 1},
#              '灵山站': {'汇通路站': 1, '东流站': 1},
#              '东流站': {'灵山站': 1, '孟北站': 1},
#              '孟北站': {'东流站': 1, '桦墅站': 1},
#              '桦墅站': {'孟北站': 1, '仙林湖站': 1},
#              '仙林湖站': {'桦墅站': 1},
#              '仙新路': {'尧化门': 1},
#              '尧化门': {'仙新路': 1, '尧化新村': 1},
#              '尧化新村': {'尧化门': 1, '丁家庄南': 1},
#              '丁家庄南': {'尧化新村': 1, '丁家庄': 1},
#              '丁家庄': {'丁家庄南': 1, '万寿': 1},
#              '万寿': {'丁家庄': 1, '晓庄': 1},
#              '幕府山': {'晓庄': 1, '五塘广场': 1},
#              '幕府西路': {'五塘广场': 1},
#              '应天大街': {'梦都大街东': 1},
#              '梦都大街东': {'应天大街': 1, '新城科技园': 1},
#              '新城科技园': {'梦都大街东': 1, '中胜': 1},
#              '中胜': {'新城科技园': 1, '嘉陵江东街': 1, '小行': 1, '元通': 1},
#              '嘉陵江东街': {'中胜': 1, '永初路': 1},
#              '永初路': {'嘉陵江东街': 1, '太清路': 1},
#              '太清路': {'永初路': 1, '螺塘路': 1},
#              '西善桥': {'螺塘路': 1},
#              '小行': {'安德门': 1, '中胜': 1},
#              '奥体中心': {'元通': 1, '梦都大街': 1},
#              '梦都大街': {'奥体中心': 1, '绿博园': 1},
#              '绿博园': {'梦都大街': 1, '江心洲': 1},
#              '江心洲': {'绿博园': 1, '临江.青奥体育公园': 1},
#              '临江.青奥体育公园': {'江心洲': 1, '浦口万汇城': 1},
#              '浦口万汇城': {'临江.青奥体育公园': 1, '南京工业大学': 1},
#              '南京工业大学': {'浦口万汇城': 1, '龙华路': 1},
#              '龙华路': {'南京工业大学': 1, '文德路': 1},
#              '文德路': {'龙华路': 1, '雨山路': 1},
#              '雨山路': {'文德路': 1},
#              '空港新城江宁站': {'禄口机场': 1, '柘塘站': 1},
#              '禄口机场': {'空港新城江宁站': 1, '翔宇路南': 1},
#              '翔宇路南': {'禄口机场': 1, '翔宇路北': 1, '铜山': 1},
#              '翔宇路北': {'翔宇路南': 1, '正方中路': 1},
#              '正方中路': {'翔宇路北': 1, '吉印大道': 1},
#              '吉印大道': {'正方中路': 1, '河海大学·佛城西路': 1},
#              '河海大学·佛城西路': {'吉印大道': 1, '翠屏山': 1},
#              '翠屏山': {'河海大学·佛城西路': 1, '南京南站': 1},
#              '景明佳园站': {'南京南站': 1, '铁心桥站': 1},
#              '铁心桥站': {'景明佳园站': 1, '春江路站': 1},
#              '春江路站': {'铁心桥站': 1, '贾西站': 1},
#              '贾西站': {'春江路站': 1, '油坊桥站': 1},
#              '油坊桥站': {'贾西站': 1, '永初路站': 1},
#              '永初路站': {'油坊桥站': 1, '平良大街站': 1},
#              '平良大街站': {'永初路站': 1, '吴侯街站': 1},
#              '吴侯街站': {'平良大街站': 1, '高庙路站': 1},
#              '高庙路站': {'吴侯街站': 1, '天保站': 1},
#              '天保站': {'高庙路站': 1, '刘村站': 1},
#              '刘村站': {'天保站': 1, '马骡圩站': 1},
#              '马骡圩站': {'刘村站': 1, '兰花塘站': 1},
#              '兰花塘站': {'马骡圩站': 1, '双垅站': 1},
#              '双垅站': {'兰花塘站': 1, '石碛河站': 1},
#              '石碛河站': {'双垅站': 1, '桥林新城站': 1},
#              '桥林新城站': {'石碛河站': 1, '林山站': 1},
#              '林山站': {'桥林新城站': 1, '高家冲站': 1},
#              '高家冲站': {'林山站': 1},
#              '白水桥': {'马群': 1, '麒麟门': 1},
#              '麒麟门': {'白水桥': 1, '东郊小镇': 1},
#              '东郊小镇': {'麒麟门': 1, '古泉': 1},
#              '古泉': {'东郊小镇': 1, '南京猿人洞': 1},
#              '南京猿人洞': {'古泉': 1, '汤山': 1},
#              '汤山': {'南京猿人洞': 1, '泉都大街': 1},
#              '泉都大街': {'汤山': 1, '黄梅': 1},
#              '黄梅': {'泉都大街': 1, '童世界': 1},
#              '童世界': {'黄梅': 1, '华阳': 1},
#              '华阳': {'童世界': 1, '崇明': 1},
#              '崇明': {'华阳': 1, '句容': 1},
#              '句容': {'崇明': 1},
#              '柘塘站': {'空港新城江宁站': 1, '空港新城溧水站': 1},
#              '空港新城溧水站': {'柘塘站': 1, '群力站': 1},
#              '群力站': {'空港新城溧水站': 1, '卧龙湖站': 1},
#              '卧龙湖站': {'群力站': 1, '溧水站': 1},
#              '溧水站': {'卧龙湖站': 1, '中山湖站': 1},
#              '中山湖站': {'溧水站': 1, '幸庄站': 1},
#              '幸庄站': {'中山湖站': 1, '无想山站': 1},
#              '无想山站': {'幸庄站': 1},
#              '长江大桥北': {'毛纺厂路': 1},
#              '毛纺厂路': {'长江大桥北': 1, '泰山新村': 1},
#              '泰山新村': {'毛纺厂路': 1, '泰冯路': 1},
#              '高新开发区': {'泰冯路': 1, '信息工程大学': 1},
#              '信息工程大学': {'高新开发区': 1, '卸甲甸': 1},
#              '卸甲甸': {'信息工程大学': 1, '大厂': 1},
#              '大厂': {'卸甲甸': 1, '葛塘': 1},
#              '葛塘': {'大厂': 1, '长芦': 1},
#              '长芦': {'葛塘': 1, '化工园': 1},
#              '化工园': {'长芦': 1, '六和开发区': 1},
#              '六和开发区': {'化工园': 1, '龙池': 1},
#              '龙池': {'六和开发区': 1, '雄州': 1},
#              '雄州': {'龙池': 1, '凤凰山公园': 1},
#              '凤凰山公园': {'雄州': 1, '方州广场': 1},
#              '方州广场': {'凤凰山公园': 1, '沈桥': 1},
#              '沈桥': {'方州广场': 1, '八百桥': 1},
#              '八百桥': {'沈桥': 1, '金牛湖': 1},
#              '金牛湖': {'八百桥': 1},
#              '铜山': {'翔宇路南': 1, '石湫': 1},
#              '石湫': {'铜山': 1, '明觉': 1},
#              '明觉': {'石湫': 1, '团结圩': 1},
#              '团结圩': {'明觉': 1, '高淳': 1},
#              '高淳': {'团结圩': 1}})
